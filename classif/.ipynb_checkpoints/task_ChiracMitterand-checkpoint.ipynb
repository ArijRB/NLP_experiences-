# %%
# %load_ext autoreload
# %autoreload 2
from tools import *
from sklearn.svm import LinearSVC
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.svm import LinearSVC
from sklearn.metrics import f1_score
import matplotlib.pyplot as plt

# %%
alltxts, all_labs = parse_ftrain_CM()

# %%
txt_test = parse_ftest()

# %%
text_train, text_test, y_train, y_test = train_test_split(alltxts, \
                                                          all_labs, \
                                                          stratify=all_labs,\
                                                          test_size=0.3,\
                                                          random_state=0)

# %%
fr_stopwords = french_stopwords()

# %% [markdown]
# Rapport 2013, Romain Ayres (meilleurs scores): (sur le site)http://www-connex.lip6.fr/~guigue/wikihomepage/uploads/Course/Ayres2013.pdf

# %% [markdown]
# On cherche à idetifier pour chaque document l'auteur. On va essayer de construire un classifieur binaire qui donne  le label “C” ou “M” à une phrase. Le nombre des phrases dites par "M" sont beaucoup plus faible que ceux dites par “C”, nous évaluerons nos performances avec le score F1.
#
# On considere les mots seperament mot par mot dans cette version

# %% [markdown]
# ### Version 0 : pas de pré-processing (remove numbers par defaut)

# %%
vectorizer0 = build_vectorizer(text_train)
X_train0 = vectorize_docs(vectorizer0, text_train) 
X_test0 = vectorize_docs(vectorizer0, text_test)
# Out:
# Removing numbers

# %%
mean_scores  = []
interval = [10**-4, 10**-3, 10**-2, 10**-1, 1, 10, 10**2, 10**3]
for C in interval:
    clf = LinearSVC(C=C,class_weight='balanced')
    scores = cross_val_score(clf, X_train0, y_train, scoring='f1_weighted', cv=10)
    mean_scores.append(np.mean(scores))
# Out:
# /Users/lauranguyen/anaconda3/lib/python3.5/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/lauranguyen/anaconda3/lib/python3.5/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/lauranguyen/anaconda3/lib/python3.5/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/lauranguyen/anaconda3/lib/python3.5/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %%
ax = plt.gca()

ax.plot(interval, mean_scores)
ax.set_xscale('log')
plt.xlabel('C')
plt.ylabel('Score F1 moyen')
plt.axis('tight')
plt.show()

# %%
max(mean_scores)
# Out:
# 0.86298446321499611

# %%
C_star = interval[np.argmax(mean_scores)]
clf0 = LinearSVC (C=C_star,class_weight='balanced')
clf0.fit(X_train0, y_train)
y_pred = clf0.predict(X_test0)
f1_score(y_test,y_pred,pos_label=-1, average='binary')
# Out:
# 0.53095752339812818

# %%
clf0 = LinearSVC(C=C_star)
pred0 = eval_on_final_test(vectorizer0, clf0, alltxts, all_labs, txt_test, 0)

# %% [markdown]
# ### Version 1: en enlevant les stopwords +lowercase

# %%
vectorizer1= build_vectorizer(text_train,stopwords=fr_stopwords, b_lowercase=False)
X_train1 = vectorize_docs(vectorizer1, text_train) 
X_test1 = vectorize_docs(vectorizer1, text_test)
# Out:
# Removing numbers
# Keeping uppercase

# %%
mean_scores  = []
interval = [10**-4, 10**-3, 10**-2, 10**-1, 1, 10, 10**2, 10**3]
for C in interval:
    clf = LinearSVC(C=C,class_weight='balanced')
    scores = cross_val_score(clf, X_train1, y_train, scoring='f1_weighted', cv=10)
    mean_scores.append(np.mean(scores))
# Out:
# /Users/lauranguyen/anaconda3/lib/python3.5/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/lauranguyen/anaconda3/lib/python3.5/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/lauranguyen/anaconda3/lib/python3.5/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/lauranguyen/anaconda3/lib/python3.5/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %%
ax = plt.gca()

ax.plot(interval, mean_scores)
ax.set_xscale('log')
plt.xlabel('C')
plt.ylabel('Score F1 moyen')
plt.axis('tight')
plt.show()

# %%
C_star = interval[np.argmax(mean_scores)]

clf1 = LinearSVC (C=C_star,class_weight='balanced')
clf1.fit(X_train1, y_train)
y_pred = clf1.predict(X_test1)
f1_score(y_test,y_pred,pos_label=-1, average='binary')
# Out:
# 0.51407196294976854

# %%
clf1 = LinearSVC(C=C_star)
pred1 = eval_on_final_test(vectorizer1, clf1, alltxts, all_labs, txt_test, 1)

# %% [markdown]
# ### Version 2a : uppercase /Removing accents/Keeping the top 10000 occurring tokens/removing stopwords

# %%
vectorizer2 = build_vectorizer(alltxts,stopwords=fr_stopwords, b_accent=False,\
                                           max_f=10000, b_lowercase=False)
X_train2 = vectorize_docs(vectorizer2, text_train) 
X_test2 = vectorize_docs(vectorizer2, text_test)
# Out:
# Removing numbers
# Keeping uppercase
# Removing accents
# Keeping the top 10000 occurring tokens

# %%
mean_scores  = []
interval = [10**-4, 10**-3, 10**-2, 10**-1, 1, 10, 10**2, 10**3]
for C in interval:
    clf = LinearSVC(C=C,class_weight='balanced')
    scores = cross_val_score(clf, X_train2, y_train, scoring='f1_weighted', cv=10)
    mean_scores.append(np.mean(scores))
# Out:
# /Users/lauranguyen/anaconda3/lib/python3.5/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/lauranguyen/anaconda3/lib/python3.5/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/lauranguyen/anaconda3/lib/python3.5/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/lauranguyen/anaconda3/lib/python3.5/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %%
ax = plt.gca()

ax.plot(interval, mean_scores)
ax.set_xscale('log')
plt.xlabel('C')
plt.ylabel('Score F1 moyen')
plt.axis('tight')
plt.show()

# %%
C_star = interval[np.argmax(mean_scores)]

clf2 = LinearSVC (C=C_star,class_weight='balanced')
clf2.fit(X_train2, y_train)
y_pred = clf2.predict(X_test2)
f1_score(y_test,y_pred,pos_label=-1, average='binary')
# Out:
# /Users/lauranguyen/anaconda3/lib/python3.5/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# 0.4196366177498253

# %%
clf2 = LinearSVC(C=C_star)
pred2 = eval_on_final_test(vectorizer2, clf2, alltxts, all_labs, txt_test, 2)

# %% [markdown]
# ### Version 2b : uppercase /Removing accents/Keeping the top 10000 occurring tokens/removing stopwords/stemming

# %%
vectorizer2b = build_vectorizer(alltxts,stopwords=fr_stopwords, b_accent=False,\
                                           max_f=10000, b_lowercase=False, b_stemming=True)
X_train2b = vectorize_docs(vectorizer2b, text_train) 
X_test2b = vectorize_docs(vectorizer2b, text_test)
# Out:
# Stemming
# Removing numbers
# Keeping uppercase
# Removing accents
# Keeping the top 10000 occurring tokens

# %%
mean_scores  = []
interval = [10**-4, 10**-3, 10**-2, 10**-1, 1, 10, 10**2, 10**3]
for C in interval:
    clf = LinearSVC(C=C,class_weight='balanced')
    scores = cross_val_score(clf, X_train2b, y_train, scoring='f1_weighted', cv=10)
    mean_scores.append(np.mean(scores))
# Out:
# /Users/lauranguyen/anaconda3/lib/python3.5/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/lauranguyen/anaconda3/lib/python3.5/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/lauranguyen/anaconda3/lib/python3.5/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/lauranguyen/anaconda3/lib/python3.5/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %%
ax = plt.gca()

ax.plot(interval, mean_scores)
ax.set_xscale('log')
plt.xlabel('C')
plt.ylabel('Score F1 moyen')
plt.axis('tight')
plt.show()

# %%
C_star = interval[np.argmax(mean_scores)]

clf2b = LinearSVC (C=C_star,class_weight='balanced')
clf2b.fit(X_train2b, y_train)
y_pred = clf2.predict(X_test2b)
f1_score(y_test,y_pred,pos_label=-1, average='binary')
# Out:
# /Users/lauranguyen/anaconda3/lib/python3.5/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# 0.15742024965325938

# %% [markdown]
# ### Version 3 : Ajouter de post processing pour enlever les elements isolés

# %%
f = open("testfile_v1.txt", "r")
s=f.read()
s = s.replace("\n","").replace("MMCMM","MMMMM").replace("CCMCC","CCCCC")\
                                        .replace("MCM","MMM").replace("CMC","CCC").replace("MCCM","MMMM")
f = open("testfile_v3.txt", "w")
f.write("\n".join(list(s))+"\n")
f.close()

# %% [markdown]
# On utilise un svm lineaire comme modele dont on cherche le parametre optimal par une cross-validation.
# Les classes n’étant pas équilibréesdans le jeu d’apprentissage, on se sert de stratified cross validation afin que les individus de chaque classe soient bien répartis .
#
# Décrire les prétraitements faits à chaque fois

# %% [markdown]
# ## Version 4 : remove numbers + 2-grammes

# %%
vectorizer4 = build_vectorizer(text_train,n=(2,2))
X_train4 = vectorize_docs(vectorizer4, text_train) 
X_test4 = vectorize_docs(vectorizer4, text_test)
# Out:
# Removing numbers

# %%
vectorizer4.get_feature_names()
# Out:
# ['abaissant les',
#  'abaissement des',
#  'abaissement du',
#  'abaissement la',
#  'abaisser de',
#  'abaisser le',
#  'abaisser les',
#  'abaisser nos',
#  'abaissé méconnu',
#  'abandon abaissement',
#  'abandon de',
#  'abandon des',
#  'abandon devant',
#  'abandon dont',
#  'abandon du',
#  'abandon elle',
#  'abandon et',
#  'abandon la',
#  'abandon le',
#  'abandon par',
#  'abandon pourrait',
#  'abandonne au',
#  'abandonne automobile',
#  'abandonne la',
#  'abandonne pas',
#  'abandonnent certaines',
#  'abandonnent des',
#  'abandonner action',
#  'abandonner afrique',
#  'abandonner au',
#  'abandonner elle',
#  'abandonner en',
#  'abandonner idée',
#  'abandonner la',
#  'abandonner les',
#  'abandonner ou',
#  'abandonner ses',
#  'abandonner trois',
#  'abandonnerai donc',
#  'abandonnons pas',
#  'abandonné au',
#  'abandonné ce',
#  'abandonné le',
#  'abandonné leur',
#  'abandonnée ou',
#  'abandonnée sauf',
#  'abandonnées autres',
#  'abandonnés eux',
#  'abandonnés leurs',
#  'abandonnés parce',
#  'abat par',
#  'abattage de',
#  'abattage des',
#  'abattage qui',
#  'abattait le',
#  'abattait tragiquement',
#  'abattent aujourd',
#  'abattre le',
#  'abattu infamie',
#  'abattues pour',
#  'abbaye aux',
#  'abbayes ce',
#  'abc comme',
#  'abdication de',
#  'abdiquer de',
#  'abdiquer leurs',
#  'abdou monsieur',
#  'aberrant amener',
#  'abidjan au',
#  'abidjan efforcent',
#  'abidjan en',
#  'abidjan je',
#  'abimer une',
#  'abm nous',
#  'abm ou',
#  'abm qui',
#  'abm scellé',
#  'abnégation avoir',
#  'abnégation des',
#  'abnégation déployés',
#  'abnégation et',
#  'abnégation quelle',
#  'abnégation tant',
#  'abois mais',
#  'abois multiplient',
#  'abolie par',
#  'abolir je',
#  'abolir les',
#  'abolirait ses',
#  'abolissent atlantique',
#  'abolissent les',
#  'abolit définitivement',
#  'abolit espace',
#  'abolit les',
#  'abolition de',
#  'abolition des',
#  'abolition du',
#  'abolition universelle',
#  'abominable exemple',
#  'abominable fléau',
#  'abominables et',
#  'abondamment traiter',
#  'abondance de',
#  'abondance pourrait',
#  'abondante et',
#  'abondantes après',
#  'abondantes et',
#  'abondantes servie',
#  'abonder les',
#  'abord abrogation',
#  'abord accroître',
#  'abord accueil',
#  'abord accès',
#  'abord achever',
#  'abord adresser',
#  'abord affaiblissement',
#  'abord affaire',
#  'abord affirmation',
#  'abord affirmer',
#  'abord affronter',
#  'abord afghanistan',
#  'abord afin',
#  'abord afrique',
#  'abord ambition',
#  'abord amitié',
#  'abord améliorer',
#  'abord après',
#  'abord arrivée',
#  'abord associer',
#  'abord assurance',
#  'abord assurer',
#  'abord attacher',
#  'abord attirer',
#  'abord au',
#  'abord aujourd',
#  'abord autour',
#  'abord aux',
#  'abord avant',
#  'abord avec',
#  'abord avoir',
#  'abord besoin',
#  'abord beyrouth',
#  'abord bien',
#  'abord bienvenue',
#  'abord bâtir',
#  'abord car',
#  'abord ce',
#  'abord cela',
#  'abord celle',
#  'abord celles',
#  'abord celui',
#  'abord cette',
#  'abord ceux',
#  'abord chefs',
#  'abord cher',
#  'abord cherché',
#  'abord chez',
#  'abord clarifier',
#  'abord comme',
#  'abord comment',
#  'abord compté',
#  'abord conforter',
#  'abord constaté',
#  'abord construire',
#  'abord contre',
#  'abord culturel',
#  'abord cédé',
#  'abord dans',
#  'abord de',
#  'abord demander',
#  'abord des',
#  'abord dire',
#  'abord donner',
#  'abord doute',
#  'abord du',
#  'abord développer',
#  'abord efficacité',
#  'abord elle',
#  'abord emploi',
#  'abord en',
#  'abord entre',
#  'abord environnement',
#  'abord espoir',
#  'abord est',
#  'abord estime',
#  'abord et',
#  'abord etat',
#  'abord eu',
#  'abord europe',
#  'abord ex',
#  'abord examiner',
#  'abord exportation',
#  'abord exprimer',
#  'abord extension',
#  'abord fonder',
#  'abord féliciter',
#  'abord garantir',
#  'abord grâce',
#  'abord génétiques',
#  'abord heureux',
#  'abord hélas',
#  'abord ici',
#  'abord il',
#  'abord ils',
#  'abord image',
#  'abord immense',
#  'abord importance',
#  'abord indispensable',
#  'abord informer',
#  'abord interdiction',
#  'abord intérieur',
#  'abord intérêt',
#  'abord irak',
#  'abord je',
#  'abord la',
#  'abord le',
#  'abord les',
#  'abord leur',
#  'abord lorsqu',
#  'abord lui',
#  'abord là',
#  'abord ma',
#  'abord madagascar',
#  'abord mais',
#  'abord me',
#  'abord merci',
#  'abord mes',
#  'abord mesure',
#  'abord mesurer',
#  'abord mettons',
#  'abord mieux',
#  'abord militaire',
#  'abord mon',
#  'abord monsieur',
#  'abord naturellement',
#  'abord ne',
#  'abord nom',
#  'abord nos',
#  'abord noter',
#  'abord nous',
#  'abord nées',
#  'abord ordre',
#  'abord organiser',
#  'abord ouverture',
#  'abord où',
#  'abord par',
#  'abord parce',
#  'abord parlons',
#  'abord parlé',
#  'abord pensons',
#  'abord permettre',
#  'abord plaider',
#  'abord plus',
#  'abord porter',
#  'abord pour',
#  'abord pourquoi',
#  'abord pouvoir',
#  'abord prendre',
#  'abord préciser',
#  'abord préserver',
#  'abord puis',
#  'abord qu',
#  'abord que',
#  'abord quelques',
#  'abord qui',
#  'abord rassemblés',
#  'abord remarquablement',
#  'abord remercier',
#  'abord remédier',
#  'abord rendre',
#  'abord renforcer',
#  'abord renforcé',
#  'abord respecter',
#  'abord respectons',
#  'abord restaurer',
#  'abord retrouver',
#  'abord rudoyée',
#  'abord répondre',
#  'abord rétablir',
#  'abord réussir',
#  'abord sa',
#  'abord saluer',
#  'abord se',
#  'abord shanghai',
#  'abord si',
#  'abord sont',
#  'abord souhaiter',
#  'abord souhaité',
#  'abord sous',
#  'abord su',
#  'abord sur',
#  'abord surmonter',
#  'abord tous',
#  'abord tout',
#  'abord un',
#  'abord une',
#  'abord unir',
#  'abord vaincu',
#  'abord veiller',
#  'abord vers',
#  'abord vivre',
#  'abord votre',
#  'abord vous',
#  'abord échanger',
#  'abord échelle',
#  'abord école',
#  'abord égalité',
#  'abord égoïsme',
#  'abord établir',
#  'abord état',
#  'abord été',
#  'abord évoquer',
#  'abord être',
#  'abordait les',
#  'abordant avec',
#  'abordant de',
#  'aborde animé',
#  'aborde aujourd',
#  'aborde avec',
#  'aborde ce',
#  'aborde ces',
#  'aborde cette',
#  'aborde dans',
#  'aborde habité',
#  'aborde le',
#  'aborde libéré',
#  'aborde naturellement',
#  'aborde sans',
#  'aborde son',
#  'aborde une',
#  'aborder aussi',
#  'aborder autres',
#  'aborder avec',
#  'aborder avenir',
#  'aborder carrément',
#  'aborder ce',
#  'aborder ces',
#  'aborder cette',
#  'aborder crânement',
#  'aborder de',
#  'aborder différemment',
#  'aborder désormais',
#  'aborder en',
#  'aborder ensemble',
#  'aborder et',
#  'aborder exigence',
#  'aborder la',
#  'aborder le',
#  'aborder les',
#  'aborder leur',
#  'aborder lucidement',
#  'aborder maintenant',
#  'aborder même',
#  'aborder objet',
#  'aborder sans',
#  'aborder si',
#  'aborder son',
#  'aborder tous',
#  'aborder travers',
#  'aborder très',
#  'aborder un',
#  'aborder une',
#  'aborder véritablement',
#  'abordera cette',
#  'abordera dans',
#  'abordera il',
#  'aborderai enfin',
#  'aborderai pas',
#  'aborderait dans',
#  'aborderons aussi',
#  'aborderons dans',
#  'aborderons en',
#  'abordez votre',
#  'abordions dès',
#  'abordions les',
#  'abordons aux',
#  'abordons avec',
#  'abordons cette',
#  'abordons le',
#  'abords qui',
#  'abordé avec',
#  'abordé ce',
#  'abordé cette',
#  'abordé concerne',
#  'abordé de',
#  'abordé histoire',
#  'abordé ici',
#  'abordé le',
#  'abordé les',
#  'abordée avec',
#  'abordée dans',
#  'abordée qu',
#  'abordés dans',
#  'abordés sans',
#  'abou dabi',
#  'abouti au',
#  'abouti ce',
#  'abouti en',
#  'abouti il',
#  'abouti ne',
#  'abouti un',
#  'aboutir avant',
#  'aboutir ce',
#  'aboutir ces',
#  'aboutir dans',
#  'aboutir des',
#  'aboutir ici',
#  'aboutir il',
#  'aboutir la',
#  'aboutir le',
#  'aboutir là',
#  'aboutir parce',
#  'aboutir quelques',
#  'aboutir rapidement',
#  'aboutir très',
#  'aboutir un',
#  'aboutir une',
#  'aboutissait au',
#  'aboutissait pas',
#  'aboutissant estuaire',
#  'aboutisse ce',
#  'aboutisse cette',
#  'aboutisse dans',
#  'aboutisse le',
#  'aboutisse lors',
#  'aboutisse substituer',
#  'aboutissement de',
#  'aboutissement des',
#  'aboutissement du',
#  'aboutissement est',
#  'aboutissement et',
#  'aboutissement législatif',
#  'aboutissement légitime',
#  'aboutissement nous',
#  'aboutissement un',
#  'aboutissement une',
#  'aboutissement utile',
#  'aboutissent avant',
#  'aboutissent pas',
#  'aboutissent rapidement',
#  'aboutissent très',
#  'aboutissions gênes',
#  'aboutit distendre',
#  'aboutit une',
#  'abraham je',
#  'abraham les',
#  'abraham partout',
#  'abraham pourront',
#  'abri abri',
#  'abri comme',
#  'abri de',
#  'abri des',
#  'abri pour',
#  'abrite derrière',
#  'abrite pas',
#  'abrite trop',
#  'abrite votre',
#  'abritent des',
#  'abritent virus',
#  'abriter ces',
#  'abriter de',
#  'abriter en',
#  'abritez le',
#  'abrité depuis',
#  'abrité tout',
#  'abritées par',
#  'abrogation du',
#  'abroge ces',
#  'abscons les',
#  'absence arbitre',
#  'absence aussi',
#  'absence de',
#  'absence engagement',
#  'absence est',
#  'absence etat',
#  'absence horizon',
#  'absence peuplée',
#  'absence quasi',
#  'absence regrettable',
#  'absence un',
#  'absence une',
#  'absence économie',
#  'absence écoute',
#  'absent aujourd',
#  'absent du',
#  'absente de',
#  'absente des',
#  'absente du',
#  'absenter du',
#  'absentes du',
#  'absents chez',
#  'absents de',
#  'absents des',
#  'absents du',
#  'absentéisme premier',
#  'absolu de',
#  'absolu irrévocable',
#  'absolu israël',
#  'absolu qui',
#  'absolu son',
#  'absolue abord',
#  'absolue aux',
#  'absolue certes',
#  'absolue continuité',
#  'absolue de',
#  'absolue des',
#  'absolue doit',
#  'absolue enfin',
#  'absolue identité',
#  'absolue la',
#  'absolue le',
#  'absolue pour',
#  'absolue priorité',
#  'absolue qu',
#  'absolue qui',
#  'absolue vigilance',
#  'absolument besoin',
#  'absolument briser',
#  'absolument dramatique',
#  'absolument essentiel',
#  'absolument fascinant',
#  'absolument fixer',
#  'absolument garantir',
#  'absolument indignes',
#  'absolument indispensable',
#  'absolument indispensables',
#  'absolument la',
#  'absolument maintenir',
#  'absolument mesurer',
#  'absolument nécessaire',
#  'absolument par',
#  'absolument primordial',
#  'absolument prioritaire',
#  'absolument préserver',
#  'absolument préservée',
#  'absolument qu',
#  'absolument que',
#  'absolument redonner',
#  'absolument réagir',
#  'absolument réussir',
#  'absolument sans',
#  'absolument se',
#  'absolument spontanément',
#  'absolument sûr',
#  'absolument tisser',
#  'absolument vitale',
#  'absolument vitales',
#  'absolument votre',
#  'absolument éviter',
#  'absolument être',
#  'absolus en',
#  'absolutisme pour',
#  'absolutisme républicain',
#  'absoluà on',
#  'absorbe dans',
#  'absorbe déjà',
#  'absorbe la',
#  'absorbe une',
#  'absorber la',
#  'absorber les',
#  'absorber par',
#  'absorber toutes',
#  'absorption des',
#  'absorption nécessaire',
#  'abstenir de',
#  'abstention et',
#  'abstentionnisme le',
#  'abstraction faite',
#  'abstraction tant',
#  'abstrait et',
#  'abstrait il',
#  'abstraite des',
#  'abstraite et',
#  'abstraite trop',
#  'absurde celle',
#  'absurde de',
#  'absurde et',
#  'absurde idéologie',
#  'absurde ont',
#  'absurde que',
#  'absurde querelle',
#  'absurde vous',
#  'absurdement déchirés',
#  'absurdité de',
#  'absurdité économique',
#  'absurdités des',
#  'absurdités du',
#  'abuja en',
#  'abus alcool',
#  'abus dans',
#  'abus et',
#  'abus que',
#  'abus qui',
#  'abus sont',
#  'abus éventuels',
#  'abusait pas',
#  'abuse de',
#  'abuse souvent',
#  'abuser de',
#  'abuser par',
#  'abusive qui',
#  'abusivement menacé',
#  'abusivement utilisés',
#  'abusives les',
#  'abusives ou',
#  'abusés ou',
#  'abymes que',
#  'abîme chaque',
#  'abîme si',
#  'abîmer avec',
#  'abîmer dans',
#  'abîmer la',
#  'abîmes se',
#  'abîmée le',
#  'acadie avec',
#  'acadie de',
#  'acadie dont',
#  'acadie en',
#  'acadie et',
#  'acadie né',
#  'acadien dont',
#  'acadien fils',
#  'acadien le',
#  'acadien pour',
#  'acadienne de',
#  'acadienne dont',
#  'acadienne est',
#  'acadienne qui',
#  'acadiennes de',
#  'acadiennes et',
#  'acadiennes leur',
#  'acadiens et',
#  'académicien monsieur',
#  'académicien se',
#  'académicien vingt',
#  'académiciens membres',
#  'académie andine',
#  'académie brésilienne',
#  'académie consacrée',
#  'académie de',
#  'académie des',
#  'académie européenne',
#  'académie franco',
#  'académie française',
#  'académie il',
#  'académie internationale',
#  'académie nationale',
#  'académie polaire',
#  'académies des',
#  'académies évaluation',
#  'accablent réduire',
#  'accablé traqué',
#  'accablés de',
#  'accablés par',
#  'accaparer tous',
#  'accent abord',
#  'accent contribuer',
#  'accent doit',
#  'accent endroit',
#  'accent est',
#  'accent les',
#  'accent non',
#  'accent pour',
#  'accent soit',
#  'accent sur',
#  'accent tout',
#  'accents qui',
#  'accentuant votre',
#  'accentuation des',
#  'accentue bien',
#  'accentue de',
#  'accentue il',
#  'accentuer cette',
#  'accentuer dans',
#  'accentuer effort',
#  'accentuer encore',
#  'accentuer la',
#  'accentuer le',
#  'accentuer les',
#  'accentuer nos',
#  'accentuer surconcentration',
#  'accentuer émigration',
#  'accentué et',
#  'accentuée entre',
#  'acceptable dans',
#  'acceptable de',
#  'acceptable en',
#  'acceptable est',
#  'acceptable et',
#  'acceptable par',
#  'acceptable pour',
#  'acceptable qu',
#  'acceptable que',
#  'acceptables plus',
#  'acceptant abandon',
#  'acceptant ces',
#  'acceptant de',
#  'acceptant des',
#  'acceptant les',
#  'acceptant une',
#  'acceptation de',
#  'acceptation des',
#  'acceptation du',
#  'acceptation mutuelle',
#  'acceptation par',
#  'acceptation pleine',
#  'acceptation réelle',
#  'acceptation se',
#  'acceptation un',
#  'accepte dans',
#  'accepte de',
#  'accepte du',
#  'accepte fort',
#  'accepte la',
#  'accepte pas',
#  'acceptent aider',
#  'acceptent aller',
#  'acceptent de',
#  'acceptent ils',
#  'acceptent mieux',
#  'acceptent parfaitement',
#  'acceptent plus',
#  'accepter adhésion',
#  'accepter aggravation',
#  'accepter ajouter',
#  'accepter altérité',
#  'accepter anarchie',
#  'accepter avenir',
#  'accepter ces',
#  'accepter cette',
#  'accepter comme',
#  'accepter dans',
#  'accepter de',
#  'accepter des',
#  'accepter entrée',
#  'accepter et',
#  'accepter hérédité',
#  'accepter la',
#  'accepter le',
#  'accepter les',
#  'accepter leur',
#  'accepter maintenant',
#  'accepter monsieur',
#  'accepter ne',
#  'accepter ni',
#  'accepter par',
#  'accepter plus',
#  'accepter pour',
#  'accepter qu',
#  'accepter que',
#  'accepter refuser',
#  'accepter réfléchir',
#  'accepter tout',
#  'accepter un',
#  'accepter une',
#  'accepter également',
#  'acceptera jamais',
#  'acceptera pas',
#  'acceptera qu',
#  'accepterai demain',
#  'accepterai jamais',
#  'accepterai pas',
#  'accepterai que',
#  'accepteraient pas',
#  'accepterait aucune',
#  'accepterait de',
#  'accepterait il',
#  'accepterait inscrire',
#  'accepterait pas',
#  'accepterons aucune',
#  'accepteront de',
#  'accepteront pas',
#  'acceptez assumer',
#  'acceptez bien',
#  'acceptez de',
#  'acceptez pas',
#  'acceptions que',
#  'acceptons donc',
#  'acceptons les',
#  'acceptons pour',
#  'accepté accueil',
#  'accepté aimable',
#  'accepté aussi',
#  'accepté avec',
#  'accepté aventure',
#  'accepté cette',
#  'accepté dans',
#  'accepté de',
#  'accepté des',
#  'accepté en',
#  'accepté entre',
#  'accepté envoi',
#  'accepté et',
#  'accepté exercice',
#  'accepté immédiatement',
#  'accepté indépendance',
#  'accepté la',
#  'accepté le',
#  'accepté ni',
#  'accepté par',
#  'accepté parce',
#  'accepté pour',
#  'accepté que',
#  'accepté votre',
#  'acceptée dans',
#  'acceptée et',
#  'acceptée par',
#  'acceptée que',
#  'acceptée qui',
#  'acceptées car',
#  'acceptées de',
#  'acceptées et',
#  'acceptées par',
#  'acceptées pour',
#  'acceptées que',
#  'acceptés afin',
#  'acceptés et',
#  'acceptés mais',
#  'acceptés par',
#  'acceptés que',
#  'accessibilité du',
#  'accessibilité travers',
#  'accessible aussi',
#  'accessible aux',
#  'accessible chaque',
#  'accessible et',
#  'accessible il',
#  'accessible le',
#  'accessible les',
#  'accessible lui',
#  'accessible plus',
#  'accessible tous',
#  'accessible trop',
#  'accessibles au',
#  'accessibles aujourd',
#  'accessibles aux',
#  'accessibles ces',
#  'accessibles droit',
#  'accessibles en',
#  'accessibles et',
#  'accessibles tous',
#  'accession au',
#  'accession etat',
#  'accession indépendance',
#  'accession la',
#  'accession organisation',
#  'accession récente',
#  'accessoire dans',
#  'accessoires sans',
#  'accessoires vous',
#  'accident industriel',
#  'accident qui',
#  'accident un',
#  'accidents de',
#  'accidents domestiques',
#  'accidents détection',
#  'accidents maritimes',
#  'accidents selon',
#  'acclamation que',
#  'acclamations avançant',
#  'acclamations président',
#  'acclame comme',
#  'acclimater enraciner',
#  'accolés inscrit',
#  'accommodent pas',
#  'accommoder attendre',
#  'accommoder de',
#  'accommoder une',
#  'accomode ils',
#  'accompagna dans',
#  'accompagna la',
#  'accompagnaient nom',
#  'accompagnant abord',
#  'accompagnant ce',
#  'accompagnant chaque',
#  'accompagnant concrètement',
#  'accompagnant elles',
#  'accompagnant le',
#  'accompagnant les',
#  'accompagnateurs dans',
#  'accompagnateurs et',
#  'accompagnatrice des',
#  'accompagne aucune',
#  'accompagne aujourd',
#  'accompagne aussi',
#  'accompagne cette',
#  'accompagne chez',
#  'accompagne dans',
#  'accompagne de',
#  'accompagne désormais',
#  'accompagne et',
#  'accompagne importants',
#  'accompagne je',
#  'accompagne la',
#  'accompagne mieux',
#  'accompagne pas',
#  'accompagne que',
#  'accompagne son',
#  'accompagne une',
#  'accompagne être',
#  'accompagnement aux',
#  'accompagnement de',
#  'accompagnement des',
#  'accompagnement du',
#  'accompagnement et',
#  'accompagnement faciliter',
#  'accompagnement humain',
#  'accompagnement incitation',
#  'accompagnement indispensable',
#  'accompagnement je',
#  'accompagnement la',
#  'accompagnement ou',
#  'accompagnement psychologique',
#  'accompagnement qui',
#  'accompagnement social',
#  'accompagnement un',
#  'accompagnement éducatif',
#  'accompagnent cette',
#  'accompagnent dans',
#  'accompagnent de',
#  'accompagnent des',
#  'accompagnent effets',
#  'accompagnent est',
#  'accompagnent et',
#  'accompagnent le',
#  'accompagnent les',
#  'accompagnent marque',
#  'accompagnent ne',
#  'accompagnent notre',
#  'accompagnent partout',
#  'accompagnent pas',
#  'accompagnent que',
#  'accompagnent toujours',
#  'accompagnent toute',
#  'accompagnent un',
#  'accompagnent une',
#  'accompagnent vous',
#  'accompagner aussi',
#  'accompagner autorité',
#  'accompagner ce',
#  'accompagner ces',
#  'accompagner cette',
#  'accompagner chaque',
#  'accompagner dans',
#  'accompagner de',
#  'accompagner du',
#  'accompagner encourager',
#  'accompagner engagement',
#  'accompagner essor',
#  'accompagner et',
#  'accompagner fidèlement',
#  'accompagner ici',
#  'accompagner la',
#  'accompagner le',
#  'accompagner les',
#  'accompagner leur',
#  'accompagner longtemps',
#  'accompagner lorsqu',
#  'accompagner nos',
#  'accompagner oeuvre',
#  'accompagner par',
#  'accompagner parce',
#  'accompagner partout',
#  'accompagner plus',
#  'accompagner pour',
#  'accompagner sa',
#  'accompagner ses',
#  'accompagner son',
#  'accompagner sur',
#  'accompagner un',
#  'accompagner une',
#  'accompagner votre',
#  'accompagner évolution',
#  'accompagnera aucun',
#  'accompagnera avec',
#  'accompagnera dans',
#  'accompagnera de',
#  'accompagnera et',
#  'accompagnera je',
#  'accompagnera jusque',
#  'accompagnera ses',
#  'accompagnera techniquement',
#  'accompagnera une',
#  'accompagneront le',
#  'accompagnez les',
#  'accompagnez vos',
#  'accompagnons le',
#  'accompagné ce',
#  'accompagné dans',
#  'accompagné de',
#  'accompagné des',
#  'accompagné du',
#  'accompagné essor',
#  'accompagné histoire',
#  'accompagné la',
#  'accompagné le',
#  'accompagné mon',
#  'accompagné notre',
#  'accompagné par',
#  'accompagné particulièrement',
#  ...]

# %%
mean_scores  = []
interval = [10**-4, 10**-3, 10**-2, 10**-1, 1, 10, 10**2, 10**3]
for C in interval:
    clf = LinearSVC(C=C,class_weight='balanced')
    scores = cross_val_score(clf, X_train4, y_train, scoring='f1_weighted', cv=10)
    mean_scores.append(np.mean(scores))
# Out:
# /Users/lauranguyen/anaconda3/lib/python3.5/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/lauranguyen/anaconda3/lib/python3.5/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/lauranguyen/anaconda3/lib/python3.5/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %%
ax = plt.gca()

ax.plot(interval, mean_scores)
ax.set_xscale('log')
plt.xlabel('C')
plt.ylabel('Score F1 moyen')
plt.axis('tight')
plt.show()

# %%
C_star = interval[np.argmax(mean_scores)]
clf4 = LinearSVC (C=C_star,class_weight='balanced')
clf4.fit(X_train4, y_train)
y_pred = clf4.predict(X_test4)
f1_score(y_test,y_pred,pos_label=-1, average='binary')
# Out:
# 0.5146259383898525

# %%
clf4 = LinearSVC(C=C_star)
pred4 = eval_on_final_test(vectorizer4, clf4, alltxts, all_labs, txt_test, 4)

# %% [markdown]
# ## Version 5 : remove numbers + 3-grammes

# %%
vectorizer5 = build_vectorizer(text_train,n=(3,3))
X_train5 = vectorize_docs(vectorizer5, text_train) 
X_test5 = vectorize_docs(vectorizer5, text_test)
# Out:
# Removing numbers

# %%
vectorizer5.get_feature_names()
# Out:
# ['abaissant les bras',
#  'abaissement des coûts',
#  'abaissement du coût',
#  'abaissement la servitude',
#  'abaisser de préserver',
#  'abaisser le coût',
#  'abaisser le poids',
#  'abaisser les charges',
#  'abaisser les coûts',
#  'abaisser les prix',
#  'abaisser nos impôts',
#  'abaissé méconnu dès',
#  'abandon de chacun',
#  'abandon de etat',
#  'abandon de la',
#  'abandon de leur',
#  'abandon de soi',
#  'abandon de solitude',
#  'abandon de tout',
#  'abandon de trahison',
#  'abandon des essais',
#  'abandon devant la',
#  'abandon dont souffrent',
#  'abandon du salaire',
#  'abandon du système',
#  'abandon elle attaque',
#  'abandon et de',
#  'abandon et du',
#  'abandon la fatalité',
#  'abandon le champ',
#  'abandon par la',
#  'abandon pourrait jamais',
#  'abandonne au point',
#  'abandonne automobile ou',
#  'abandonne la plus',
#  'abandonne pas leur',
#  'abandonnent certaines incriminations',
#  'abandonnent des considérations',
#  'abandonnent des morceaux',
#  'abandonner action civique',
#  'abandonner afrique serait',
#  'abandonner au bord',
#  'abandonner au charme',
#  'abandonner elle même',
#  'abandonner en quoi',
#  'abandonner idée élaborer',
#  'abandonner la fatalité',
#  'abandonner la primauté',
#  'abandonner les choix',
#  'abandonner les mécanismes',
#  'abandonner les objectifs',
#  'abandonner ou relâcher',
#  'abandonner ses anciennes',
#  'abandonner trois convictions',
#  'abandonnerai donc pas',
#  'abandonnons pas les',
#  'abandonné au seul',
#  'abandonné ce qu',
#  'abandonné le meilleur',
#  'abandonné leur vocation',
#  'abandonnée ou déléguée',
#  'abandonnée sauf si',
#  'abandonnées autres qu',
#  'abandonnés eux mêmes',
#  'abandonnés leurs difficultés',
#  'abandonnés parce que',
#  'abat par priorité',
#  'abattage de nombreux',
#  'abattage des produits',
#  'abattage qui va',
#  'abattait le mur',
#  'abattait tragiquement sur',
#  'abattent aujourd hui',
#  'abattre le nom',
#  'abattues pour les',
#  'abbaye aux dames',
#  'abbaye aux hommes',
#  'abbayes ce lycée',
#  'abc comme machiniste',
#  'abdication de autorité',
#  'abdiquer de sa',
#  'abdiquer leurs responsabilités',
#  'abdou monsieur le',
#  'aberrant amener certains',
#  'abidjan au sujet',
#  'abidjan efforcent de',
#  'abidjan en ce',
#  'abidjan je plaidais',
#  'abimer une vie',
#  'abm nous devons',
#  'abm ou en',
#  'abm qui demeure',
#  'abm scellé équilibre',
#  'abnégation avoir évité',
#  'abnégation des vôtres',
#  'abnégation déployés quotidiennement',
#  'abnégation et je',
#  'abnégation quelle ténacité',
#  'abnégation tant de',
#  'abois mais les',
#  'abois multiplient les',
#  'abolie par plus',
#  'abolir je vous',
#  'abolir les haines',
#  'abolirait ses différences',
#  'abolissent atlantique entre',
#  'abolissent les frontières',
#  'abolit définitivement esclavage',
#  'abolit les distances',
#  'abolition de la',
#  'abolition des frontières',
#  'abolition du travail',
#  'abolition universelle de',
#  'abominable exemple des',
#  'abominables et inacceptables',
#  'abondance de ces',
#  'abondance pourrait se',
#  'abondante et bon',
#  'abondante et la',
#  'abondantes après tant',
#  'abondantes et variées',
#  'abondantes servie par',
#  'abonder les comptes',
#  'abord abrogation du',
#  'abord accroître les',
#  'abord accueil de',
#  'abord accès aux',
#  'abord achever et',
#  'abord adresser mes',
#  'abord affaiblissement de',
#  'abord affaire de',
#  'abord affirmation une',
#  'abord affirmer la',
#  'abord affronter annonce',
#  'abord afin agir',
#  'abord ambition de',
#  'abord amitié franco',
#  'abord améliorer sa',
#  'abord après avoir',
#  'abord arrivée de',
#  'abord associer hommage',
#  'abord assurance pour',
#  'abord assurance un',
#  'abord assurer la',
#  'abord assurer égalité',
#  'abord attacher traiter',
#  'abord attirer activité',
#  'abord au cours',
#  'abord au liban',
#  'abord au maroc',
#  'abord au niveau',
#  'abord au premier',
#  'abord au prodigieux',
#  'abord au sein',
#  'abord au service',
#  'abord au sida',
#  'abord au souvenir',
#  'abord au travail',
#  'abord aujourd hui',
#  'abord autour de',
#  'abord aux côtés',
#  'abord aux deux',
#  'abord aux etats',
#  'abord aux nations',
#  'abord aux portes',
#  'abord aux protagonistes',
#  'abord aux salariés',
#  'abord aux étudiantes',
#  'abord avant le',
#  'abord avec beaucoup',
#  'abord avec cracovie',
#  'abord avec le',
#  'abord avoir conscience',
#  'abord besoin un',
#  'abord bien sûr',
#  'abord bienvenue chacune',
#  'abord bâtir un',
#  'abord car les',
#  'abord ce est',
#  'abord ce message',
#  'abord ce partenariat',
#  'abord ce que',
#  'abord ce qui',
#  'abord ce regard',
#  'abord cela la',
#  'abord celle de',
#  'abord celle des',
#  'abord celle entreprendre',
#  'abord celles qui',
#  'abord celui de',
#  'abord celui des',
#  'abord celui une',
#  'abord cette fraternité',
#  'abord ceux du',
#  'abord ceux qui',
#  'abord chefs entreprises',
#  'abord cher monsieur',
#  'abord cher nom',
#  'abord cherché celle',
#  'abord chez jeanne',
#  'abord chez moi',
#  'abord chez nous',
#  'abord clarifier les',
#  'abord comme un',
#  'abord comment assurer',
#  'abord compté sur',
#  'abord conforter la',
#  'abord constaté que',
#  'abord construire ensemble',
#  'abord construire une',
#  'abord contre son',
#  'abord contre un',
#  'abord cédé au',
#  'abord dans ce',
#  'abord dans chacun',
#  'abord dans idée',
#  'abord dans intérêt',
#  'abord dans la',
#  'abord dans le',
#  'abord dans les',
#  'abord dans sa',
#  'abord de bâtir',
#  'abord de celle',
#  'abord de celui',
#  'abord de ceux',
#  'abord de conforter',
#  'abord de continuer',
#  'abord de décréter',
#  'abord de façon',
#  'abord de france',
#  'abord de ignorance',
#  'abord de la',
#  'abord de libérer',
#  'abord de nos',
#  'abord de organisation',
#  'abord de percevoir',
#  'abord de pouvoir',
#  'abord de préoccupations',
#  'abord de préserver',
#  'abord de quel',
#  'abord de revenir',
#  'abord de règles',
#  'abord de sa',
#  'abord de saluer',
#  'abord de stabilité',
#  'abord de vaincre',
#  'abord de vos',
#  'abord de votre',
#  'abord de vous',
#  'abord de échange',
#  'abord demander etat',
#  'abord des artistes',
#  'abord des crises',
#  'abord des emplois',
#  'abord des entreprises',
#  'abord des hommes',
#  'abord des juifs',
#  'abord des partenaires',
#  'abord des plus',
#  'abord des professionnels',
#  'abord des réalités',
#  'abord des sentiments',
#  'abord des soldats',
#  'abord des travailleurs',
#  'abord des vertus',
#  'abord dire bravo',
#  'abord dire combien',
#  'abord dire la',
#  'abord donner toute',
#  'abord doute elle',
#  'abord du destin',
#  'abord du premier',
#  'abord du respect',
#  'abord développer et',
#  'abord développer largement',
#  'abord efficacité de',
#  'abord elle conforté',
#  'abord elle même',
#  'abord en afrique',
#  'abord en baissant',
#  'abord en cette',
#  'abord en donnant',
#  'abord en favorisant',
#  'abord en le',
#  'abord en luttant',
#  'abord en matière',
#  'abord en ne',
#  'abord en nous',
#  'abord en pensant',
#  'abord en raison',
#  'abord en renforçant',
#  'abord en réaffirmant',
#  'abord en tant',
#  'abord en terme',
#  'abord en travaillant',
#  'abord en veillant',
#  'abord en votre',
#  'abord entre français',
#  'abord entre les',
#  'abord entre nos',
#  'abord entre vos',
#  'abord environnement économique',
#  'abord espoir de',
#  'abord est la',
#  'abord est notre',
#  'abord estime et',
#  'abord et avant',
#  'abord et avec',
#  'abord et de',
#  'abord et ensuite',
#  'abord et est',
#  'abord et il',
#  'abord et la',
#  'abord et le',
#  'abord et merci',
#  'abord et peut',
#  'abord et surtout',
#  'abord et vous',
#  'abord etat de',
#  'abord etat doit',
#  'abord eu le',
#  'abord europe doit',
#  'abord ex yougoslavie',
#  'abord examiner les',
#  'abord exportation le',
#  'abord exprimer ma',
#  'abord extension progressive',
#  'abord fonder ses',
#  'abord féliciter mes',
#  'abord garantir tous',
#  'abord grâce vous',
#  'abord génétiques des',
#  'abord heureux naturellement',
#  'abord hélas évoquer',
#  'abord ici dans',
#  'abord il avait',
#  'abord il faudra',
#  'abord il faut',
#  'abord il leur',
#  'abord ils demandent',
#  'abord image un',
#  'abord immense plaisir',
#  'abord importance de',
#  'abord indispensable de',
#  'abord interdiction des',
#  'abord intérieur des',
#  'abord intérêt que',
#  'abord je ai',
#  'abord je opposerai',
#  'abord je pense',
#  'abord je voudrais',
#  'abord je vous',
#  'abord la branche',
#  'abord la confiance',
#  'abord la croissance',
#  'abord la diversité',
#  'abord la décision',
#  'abord la déconcentration',
#  'abord la fin',
#  'abord la fondation',
#  'abord la france',
#  'abord la grande',
#  'abord la généralisation',
#  'abord la juste',
#  'abord la limite',
#  'abord la lutte',
#  'abord la maîtrise',
#  'abord la même',
#  'abord la paix',
#  'abord la place',
#  'abord la possibilité',
#  'abord la proximité',
#  'abord la qualité',
#  'abord la question',
#  'abord la raccorder',
#  'abord la rançon',
#  'abord la reconnaissance',
#  'abord la responsabilité',
#  'abord la solidarité',
#  'abord la tendance',
#  'abord la traduire',
#  'abord la vôtre',
#  'abord le berceau',
#  'abord le chômage',
#  'abord le connaître',
#  'abord le contrat',
#  'abord le dialogue',
#  'abord le développement',
#  'abord le fait',
#  'abord le français',
#  'abord le fruit',
#  'abord le garant',
#  'abord le mérite',
#  'abord le paysage',
#  'abord le plaisir',
#  'abord le regard',
#  'abord le resserrement',
#  'abord le règlement',
#  'abord le sentiment',
#  'abord le sida',
#  'abord le signe',
#  'abord le souhait',
#  'abord le succès',
#  'abord le tiers',
#  'abord les formes',
#  'abord les infirmières',
#  'abord les institutions',
#  'abord les instruments',
#  'abord les jeunes',
#  'abord les langues',
#  'abord les legs',
#  'abord les maires',
#  'abord les moins',
#  'abord les nations',
#  'abord les nôtres',
#  'abord les opérations',
#  'abord les partenaires',
#  'abord les plus',
#  'abord les premiers',
#  'abord les responsables',
#  'abord les ressources',
#  'abord les vôtres',
#  'abord leur succès',
#  'abord leur sécurité',
#  'abord leur terroir',
#  'abord lorsqu il',
#  'abord lui donner',
#  'abord là sur',
#  'abord ma joie',
#  'abord madagascar maurice',
#  'abord mais aussi',
#  'abord me semble',
#  'abord merci de',
#  'abord merci pour',
#  'abord mes propos',
#  'abord mesure que',
#  'abord mesurer les',
#  'abord mettons un',
#  'abord mieux asseoir',
#  'abord mieux informer',
#  'abord militaire il',
#  'abord mon cher',
#  'abord monsieur le',
#  'abord naturellement excellence',
#  'abord naturellement un',
#  'abord ne pas',
#  'abord nom de',
#  'abord nom le',
#  'abord nom que',
#  'abord nom qui',
#  'abord nos entreprises',
#  'abord nos jeunesses',
#  'abord noter importance',
#  'abord nous devons',
#  'abord nous donner',
#  'abord nous maintenons',
#  'abord nous représente',
#  'abord nées de',
#  'abord ordre républicain',
#  'abord organiser le',
#  'abord ouverture du',
#  'abord où de',
#  'abord où nos',
#  'abord où parlerait',
#  'abord par assainissement',
#  'abord par ce',
#  'abord par cela',
#  'abord par cette',
#  'abord par des',
#  'abord par la',
#  'abord par le',
#  'abord par son',
#  'abord par trop',
#  'abord par un',
#  'abord par une',
#  'abord par épanouissement',
#  'abord parce qu',
#  'abord parce que',
#  'abord parce vous',
#  'abord parlons de',
#  'abord parlé de',
#  'abord parlé des',
#  'abord pensons au',
#  'abord permettre aux',
#  'abord plaider pour',
#  'abord plus de',
#  'abord plus tard',
#  'abord porter un',
#  'abord pour chaque',
#  'abord pour construire',
#  'abord pour enraciner',
#  'abord pour eux',
#  'abord pour la',
#  'abord pour les',
#  'abord pour moi',
#  'abord pour oeil',
#  'abord pour pouvoir',
#  'abord pour présenter',
#  'abord pour rester',
#  'abord pour réaliser',
#  'abord pour réussir',
#  'abord pour satisfaire',
#  'abord pour tous',
#  'abord pour votre',
#  'abord pourquoi aujourd',
#  'abord pouvoir retrouver',
#  'abord prendre acte',
#  'abord prendre toute',
#  'abord préciser les',
#  'abord préserver le',
#  'abord puis aux',
#  'abord puis brest',
#  'abord puis en',
#  'abord puis expansion',
#  'abord puis par',
#  'abord qu elle',
#  'abord qu une',
#  'abord que cela',
#  'abord que je',
#  'abord que la',
#  'abord que le',
#  'abord que les',
#  'abord que nous',
#  'abord que repose',
#  'abord que soit',
#  'abord que vous',
#  'abord quelques mots',
#  'abord qui construit',
#  'abord qui est',
#  'abord qui fait',
#  'abord qui ignoraient',
#  'abord qui nous',
#  'abord qui porté',
#  'abord qui va',
#  'abord rassemblés dans',
#  'abord remarquablement organisé',
#  'abord remercier chacune',
#  'abord remercier chaleureusement',
#  'abord remercier de',
#  'abord remercier et',
#  'abord remercier institut',
#  'abord remercier le',
#  'abord remercier les',
#  'abord remercier monsieur',
#  'abord remédier aux',
#  'abord rendre hommage',
#  'abord rendre union',
#  'abord renforcer considérablement',
#  'abord renforcer le',
#  'abord renforcer les',
#  'abord renforcer sa',
#  'abord renforcé la',
#  'abord respecter le',
#  'abord respectons et',
#  'abord restaurer la',
#  'abord retrouver tout',
#  'abord rudoyée puis',
#  'abord répondre aux',
#  'abord répondre des',
#  'abord rétablir la',
#  'abord réussir la',
#  'abord sa diversité',
#  'abord sa professionnalisation',
#  'abord sa source',
#  'abord saluer ce',
#  'abord saluer chacune',
#  'abord saluer de',
#  'abord saluer et',
#  'abord saluer la',
#  'abord saluer le',
#  'abord saluer les',
#  'abord saluer nos',
#  'abord saluer si',
#  'abord saluer très',
#  'abord saluer un',
#  'abord se donner',
#  'abord se imposer',
#  'abord se reconnaître',
#  'abord se rencontrer',
#  'abord se respecter',
#  'abord shanghai rayonneront',
#  'abord si nous',
#  'abord sont au',
#  'abord souhaiter chacune',
#  'abord souhaité porter',
#  'abord sous la',
#  'abord su tirer',
#  'abord sur action',
#  'abord sur celui',
#  'abord sur des',
#  'abord sur la',
#  'abord sur le',
#  'abord sur les',
#  'abord sur notre',
#  'abord sur ses',
#  'abord sur trente',
#  'abord sur une',
#  'abord sur vous',
#  'abord surmonter des',
#  'abord tous nos',
#  'abord tout jeune',
#  'abord tout le',
#  'abord un acte',
#  'abord un apprentissage',
#  'abord un changement',
#  'abord un demi',
#  'abord un devoir',
#  'abord un défi',
#  'abord un emploi',
#  'abord un facteur',
#  'abord un homme',
#  'abord un langage',
#  'abord un message',
#  'abord un monde',
#  'abord un mot',
#  'abord un pays',
#  'abord un principe',
#  'abord un problème',
#  'abord un projet',
#  'abord un style',
#  'abord un très',
#  'abord un témoignage',
#  'abord un état',
#  'abord une adhésion',
#  'abord une affaire',
#  'abord une aide',
#  'abord une ambition',
#  'abord une approche',
#  'abord une carrière',
#  'abord une certaine',
#  'abord une communauté',
#  'abord une compétence',
#  'abord une conviction',
#  'abord une croissance',
#  'abord une demande',
#  'abord une des',
#  'abord une europe',
#  'abord une exigence',
#  'abord une fatigue',
#  'abord une façon',
#  'abord une formation',
#  'abord une forteresse',
#  'abord une france',
#  'abord une fraternité',
#  'abord une lourde',
#  'abord une marine',
#  'abord une même',
#  'abord une question',
#  'abord une relation',
#  'abord une société',
#  'abord une vision',
#  'abord unir nos',
#  'abord vaincu et',
#  'abord veiller au',
#  'abord vers les',
#  'abord vers un',
#  'abord vivre une',
#  'abord votre capacité',
#  'abord vous cher',
#  'abord vous de',
#  'abord vous dire',
#  'abord vous décideurs',
#  'abord vous en',
#  'abord vous exprimer',
#  'abord vous faire',
#  'abord vous monsieur',
#  'abord vous qui',
#  'abord vous remercier',
#  'abord vous souhaiter',
#  'abord échanger leurs',
#  'abord échelle de',
#  'abord école des',
#  'abord école pour',
#  'abord égalité des',
#  'abord égoïsme le',
#  'abord établir au',
#  'abord état agir',
#  'abord été des',
#  'abord été reconnus',
#  'abord été un',
#  'abord évoquer le',
#  'abord évoquer les',
#  'abord être capable',
#  'abord être confronté',
#  'abord être conçus',
#  'abord être le',
#  'abord être optimistes',
#  'abord être plus',
#  'abord être saisis',
#  'abord être soucieux',
#  'abordait les questions',
#  'abordant avec confiance',
#  'abordant de votre',
#  'aborde animé par',
#  'aborde aujourd hui',
#  'aborde avec ambition',
#  'aborde avec confiance',
#  'aborde avec toute',
#  'aborde ce dossier',
#  'aborde ce débat',
#  'aborde ces matières',
#  'aborde cette ambition',
#  'aborde cette période',
#  'aborde cette étape',
#  'aborde dans esprit',
#  'aborde habité par',
#  'aborde le deuxième',
#  'aborde libéré de',
#  'aborde naturellement dans',
#  'aborde sans priori',
#  'aborde son avenir',
#  'aborde une nouvelle',
#  'aborder aussi autres',
#  'aborder autres points',
#  'aborder avec ambition',
#  'aborder avec confiance',
#  'aborder avec dynamisme',
#  'aborder avec franchise',
#  'aborder avec lui',
#  'aborder avec plus',
#  'aborder avenir avec',
#  'aborder avenir dans',
#  'aborder carrément les',
#  'aborder ce débat',
#  'aborder ce début',
#  'aborder ces marchés',
#  'aborder cette question',
#  'aborder crânement son',
#  'aborder de front',
#  'aborder de plein',
#  'aborder différemment nombre',
#  'aborder désormais la',
#  'aborder en acceptant',
#  'aborder en confiance',
#  'aborder en priorité',
#  'aborder ensemble avec',
#  'aborder ensemble avenir',
#  'aborder ensemble les',
#  'aborder ensemble nos',
#  'aborder ensemble tout',
#  'aborder et approfondir',
#  'aborder exigence de',
#  'aborder la prochaine',
#  'aborder la question',
#  'aborder le regard',
#  'aborder le xxième',
#  'aborder les chemins',
#  'aborder les défis',
#  'aborder les grands',
#  'aborder les problèmes',
#  'aborder les questions',
#  'aborder les technologies',
#  'aborder les temps',
#  'aborder leur avenir',
#  'aborder lucidement nos',
#  'aborder maintenant le',
#  'aborder même dans',
#  'aborder objet même',
#  'aborder sans heurt',
#  'aborder si on',
#  'aborder son devenir',
#  'aborder tous les',
#  'aborder travers étude',
#  'aborder très clairement',
#  'aborder un problème',
#  'aborder une question',
#  'aborder véritablement au',
#  'abordera cette discussion',
#  'abordera dans le',
#  'abordera il ses',
#  'aborderai enfin la',
#  'aborderai pas ensemble',
#  'aborderait dans de',
#  'aborderons aussi en',
#  'aborderons dans sa',
#  'aborderons en commun',
#  'abordez votre propre',
#  'abordions dès maintenant',
#  'abordions les solutions',
#  'abordons aux rives',
#  'abordons avec confiance',
#  'abordons avec lucidité',
#  'abordons avec pragmatisme',
#  'abordons cette nouvelle',
#  'abordons le avec',
#  'abordons le ensemble',
#  'abordons le xxie',
#  'abords qui offrent',
#  'abordé avec plus',
#  'abordé ce matin',
#  'abordé cette nouvelle',
#  'abordé concerne les',
#  'abordé de deux',
#  'abordé histoire littéraire',
#  'abordé ici mais',
#  'abordé le problème',
#  'abordé les problèmes',
#  'abordée avec sérénité',
#  'abordée dans un',
#  'abordée qu indirectement',
#  'abordés dans la',
#  'abordés dans une',
#  'abordés sans détour',
#  'abou dabi et',
#  'abouti au dépôt',
#  'abouti ce programme',
#  'abouti en septembre',
#  'abouti il est',
#  'abouti ne laissent',
#  'abouti un pacte',
#  'aboutir avant échéance',
#  'aboutir ce grand',
#  'aboutir ces projets',
#  'aboutir dans le',
#  'aboutir dans un',
#  'aboutir des accords',
#  'aboutir des conclusions',
#  'aboutir des décisions',
#  'aboutir des propositions',
#  'aboutir des réponses',
#  'aboutir ici date',
#  'aboutir ici istanbul',
#  'aboutir il agit',
#  'aboutir la signature',
#  'aboutir le plus',
#  'aboutir là où',
#  'aboutir parce que',
#  'aboutir quelques mois',
#  'aboutir rapidement un',
#  'aboutir très bientôt',
#  'aboutir un abattage',
#  'aboutir un meilleur',
#  'aboutir une solution',
#  'aboutissait au grand',
#  'aboutissait pas rapidement',
#  'aboutissant estuaire du',
#  'aboutisse ce projet',
#  'aboutisse cette négociation',
#  'aboutisse dans les',
#  'aboutisse le plus',
#  'aboutisse lors du',
#  'aboutisse substituer une',
#  'aboutissement de cette',
#  'aboutissement de notre',
#  'aboutissement de plusieurs',
#  'aboutissement des enquêtes',
#  'aboutissement des négociations',
#  'aboutissement des travaux',
#  'aboutissement du remarquable',
#  'aboutissement est le',
#  'aboutissement et un',
#  'aboutissement législatif et',
#  'aboutissement légitime de',
#  'aboutissement nous disposerons',
#  'aboutissement un commencement',
#  'aboutissement un long',
#  'aboutissement un projet',
#  'aboutissement une convention',
#  'aboutissement une crise',
#  'aboutissement une longue',
#  'aboutissement une patiente',
#  'aboutissement utile qui',
#  'aboutissent avant la',
#  'aboutissent pas nécessairement',
#  'aboutissent très vite',
#  'aboutissions gênes dans',
#  'aboutit distendre des',
#  'aboutit une sélection',
#  'abraham je suis',
#  'abraham les trois',
#  'abraham partout où',
#  'abraham pourront chacun',
#  'abri abri des',
#  'abri comme le',
#  'abri de bien',
#  'abri de ce',
#  'abri de ces',
#  'abri de la',
#  'abri de ses',
#  'abri de tous',
#  'abri des catastrophes',
#  'abri des dangers',
#  'abri des difficultés',
#  'abri des marées',
#  'abri des meilleures',
#  'abri des tempêtes',
#  'abri des vents',
#  'abri pour qui',
#  'abrite derrière des',
#  'abrite pas derrière',
#  'abrite trop souvent',
#  'abrite votre ville',
#  'abritent des communautés',
#  'abritent virus et',
#  'abriter ces échanges',
#  'abriter de se',
#  'abriter en son',
#  'abritez le siège',
#  'abrité depuis des',
#  'abrité tout au',
#  'abritées par des',
#  'abrogation du ticket',
#  'abroge ces lois',
#  'abscons les déroutent',
#  'absence arbitre impose',
#  'absence de barrières',
#  'absence de bonne',
#  'absence de certaines',
#  'absence de certitude',
#  'absence de civisme',
#  'absence de communication',
#  'absence de contrôle',
#  'absence de dialogue',
#  'absence de déconcentration',
#  'absence de développement',
#  'absence de europe',
#  'absence de favoritisme',
#  'absence de leurs',
#  'absence de liberté',
#  'absence de logement',
#  'absence de lucidité',
#  'absence de modèles',
#  'absence de moralité',
#  'absence de perspective',
#  'absence de politique',
#  'absence de prise',
#  'absence de repères',
#  'absence de respect',
#  'absence de responsabilité',
#  'absence de règles',
#  'absence de réelle',
#  'absence de régulation',
#  'absence de soins',
#  'absence de structures',
#  'absence de toute',
#  'absence de vigilance',
#  'absence de véritable',
#  'absence engagement réel',
#  'absence est aujourd',
#  'absence est plus',
#  'absence etat les',
#  'absence horizon et',
#  'absence peuplée de',
#  'absence quasi totale',
#  'absence regrettable de',
#  'absence un bon',
#  'absence une absence',
#  'absence économie ouverte',
#  'absence écoute et',
#  'absent aujourd hui',
#  'absent du paysage',
#  'absente de notre',
#  'absente des affaires',
#  'absente du proche',
#  'absenter du péril',
#  'absentes du débat',
#  'absents chez les',
#  'absents de la',
#  'absents des listes',
#  'absents du louvre',
#  'absentéisme premier symptôme',
#  'absolu de cette',
#  'absolu de équité',
#  'absolu irrévocable et',
#  'absolu israël vivre',
#  'absolu qui impose',
#  'absolu son rapport',
#  'absolue abord école',
#  'absolue aux lois',
#  'absolue certes derrière',
#  'absolue continuité une',
#  'absolue de baisser',
#  'absolue de créer',
#  'absolue de regagner',
#  'absolue de repères',
#  'absolue de toute',
#  'absolue des principes',
#  'absolue doit être',
#  'absolue enfin ce',
#  'absolue la mise',
#  'absolue le deuxième',
#  'absolue pour tous',
#  'absolue priorité des',
#  'absolue priorité la',
#  'absolue qu elle',
#  'absolue qui est',
#  'absolument besoin pour',
#  'absolument dramatique angoissante',
#  'absolument essentiel dans',
#  'absolument fascinant je',
#  'absolument fixer une',
#  'absolument garantir sur',
#  'absolument indispensable avant',
#  'absolument indispensable que',
#  'absolument indispensables intelligence',
#  'absolument la magnifier',
#  'absolument maintenir défendre',
#  'absolument mesurer les',
#  'absolument nécessaire la',
#  'absolument nécessaire pour',
#  ...]

# %%
mean_scores  = []
interval = [10**-4, 10**-3, 10**-2, 10**-1, 1, 10, 10**2, 10**3]
for C in interval:
    clf = LinearSVC(C=C,class_weight='balanced')
    scores = cross_val_score(clf, X_train5, y_train, scoring='f1_weighted', cv=10)
    mean_scores.append(np.mean(scores))
# Out:
# /Users/lauranguyen/anaconda3/lib/python3.5/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/lauranguyen/anaconda3/lib/python3.5/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/lauranguyen/anaconda3/lib/python3.5/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %%
ax = plt.gca()

ax.plot(interval, mean_scores)
ax.set_xscale('log')
plt.xlabel('C')
plt.ylabel('Score F1 moyen')
plt.axis('tight')
plt.show()

# %%
C_star = interval[np.argmax(mean_scores)]

clf5 = LinearSVC (C=C_star,class_weight='balanced')
clf5.fit(X_train5, y_train)
y_pred = clf5.predict(X_test5)
f1_score(y_test,y_pred,pos_label=-1, average='binary')
# Out:
# 0.3901386748844376

# %%
clf5 = LinearSVC(C=C_star)
pred5 = eval_on_final_test(vectorizer5, clf5, alltxts, all_labs, txt_test, 5)

# %% [markdown]
# ## Version 6 : uppercase /Removing accents/Keeping the top 10000 occurring tokens/removing stopwords   3-grammes

# %%
vectorizer6 = build_vectorizer(alltxts,stopwords=fr_stopwords,\
                         b_lowercase=False, b_accent=False,\
                                           max_f=10000,n=(2,2))
X_train6 = vectorize_docs(vectorizer6, text_train) 
X_test6 = vectorize_docs(vectorizer6, text_test)
# Out:
# Removing numbers
# Keeping uppercase
# Removing accents
# Keeping the top 10000 occurring tokens

# %%
mean_scores  = []
interval = [10**-4, 10**-3, 10**-2, 10**-1, 1, 10, 10**2, 10**3]
for C in interval:
    clf = LinearSVC(C=C,class_weight='balanced')
    scores = cross_val_score(clf, X_train6, y_train, scoring='f1_weighted', cv=10)
    mean_scores.append(np.mean(scores))
# Out:
# /Users/lauranguyen/anaconda3/lib/python3.5/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/lauranguyen/anaconda3/lib/python3.5/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/lauranguyen/anaconda3/lib/python3.5/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %%
ax = plt.gca()

ax.plot(interval, mean_scores)
ax.set_xscale('log')
plt.xlabel('C')
plt.ylabel('Score F1 moyen')
plt.axis('tight')
plt.show()

# %%
C_star = interval[np.argmax(mean_scores)]

clf6 = LinearSVC (C=C_star,class_weight='balanced')
clf6.fit(X_train5, y_train)
y_pred = clf5.predict(X_test5)
f1_score(y_test,y_pred,pos_label=-1, average='binary')
# Out:
# 0.22361710474695956

# %%
clf6 = LinearSVC(C=C_star)
pred6 = eval_on_final_test(vectorizer6, clf6, alltxts, all_labs, txt_test, 6)

# %% [markdown]
# les ngram consiste à prendre des tuples  de n mots consécutifs. Le nombre de dimension augmente très rapidement avec la taille des n-gram, ce qui dégrade la performance de modéle . ( je pense )
