# %%
# %load_ext autoreload
# %autoreload 2
from tools import *
from sklearn.svm import LinearSVC
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.svm import LinearSVC
from sklearn.metrics import f1_score
import matplotlib.pyplot as plt

# %%
alltxts,all_labs=parse_movies()

# %%
text_train, text_test, y_train, y_test = train_test_split(alltxts, \
                                                          all_labs, \
                                                          stratify=all_labs,\
                                                          test_size=0.3,\
                                                          random_state=0)

# %%
stop_words = english_stopwords()

# %%
txt_test = parse_ftest(fname ="moviesTest/testSentiment.txt")

# %%
print(np.count_nonzero(np.array(all_labs)== -1))
print(np.count_nonzero(np.array(all_labs)== 1))
#on a les donnees equilibrées donc on va calculer l'accuracy pour évaluer notre modéle
# Out:
# 1000
# 1000

# %% [markdown]
# ### Version 0 : pas de pré-processing

# %%
vectorizer0 = build_vectorizer(text_train,b_rmnumbers=False,l=1)
X_train0 = vectorize_docs(vectorizer0, text_train) 
X_test0 = vectorize_docs(vectorizer0, text_test)

# %%
mean_scores  = []
interval = [10**-4, 10**-3, 10**-2, 10**-1, 1, 10, 10**2, 10**3]
for C in interval:
    clf = LinearSVC(C=C,class_weight='balanced')
    scores = cross_val_score(clf, X_train0, y_train, cv=10)
    mean_scores.append(np.mean(scores))

# %%
plt.plot(mean_scores) 
plt.show()

# %%
C_star = interval[np.argmax(mean_scores)]

clf0 = LinearSVC (C=C_star,class_weight='balanced')
clf0.fit(X_train0, y_train)
clf0.score(X_test0,y_test)
# Out:
# 0.8133333333333334

# %%
clf0 = LinearSVC(C=C_star)
pred0 = eval_on_final_test(vectorizer0, clf0, alltxts, all_labs, txt_test,0,l=1)
#score sur serveur 0.788488460462

# %% [markdown]
# ### Version 1: en enlevant les stopwords +lowercase+remove numbers

# %%
vectorizer1= build_vectorizer(text_train,stopwords=stop_words,l=1, b_lowercase=False)
X_train1 = vectorize_docs(vectorizer1, text_train) 
X_test1 = vectorize_docs(vectorizer1, text_test)
# Out:
# Removing numbers
# Keeping uppercase

# %%
mean_scores  = []
interval = [10**-4, 10**-3, 10**-2, 10**-1, 1, 10, 10**2, 10**3]
for C in interval:
    clf = LinearSVC(C=C,class_weight='balanced')
    scores = cross_val_score(clf, X_train1, y_train, cv=10)
    mean_scores.append(np.mean(scores))

# %%
plt.plot(mean_scores) 
plt.show()

# %%
C_star = interval[np.argmax(mean_scores)]

clf1 = LinearSVC (C=C_star,class_weight='balanced')
clf1.fit(X_train1, y_train)
clf1.score(X_test1,y_test)
# Out:
# 0.8216666666666667

# %%
clf1 = LinearSVC(C=C_star)
pred1 = eval_on_final_test(vectorizer1, clf1, alltxts, all_labs, txt_test, 1,l=1)
#score sur serveur 0.788488460462

# %% [markdown]
# ### Version 2 : uppercase /Removing accents/Keeping the top 10000 occurring tokens+remove numbers

# %%
vectorizer2 = build_vectorizer(alltxts,stopwords=stop_words, b_accent=False,\
                                           max_f=10000,l=1)
X_train2 = vectorize_docs(vectorizer2, text_train) 
X_test2 = vectorize_docs(vectorizer2, text_test)
# Out:
# Removing numbers
# Removing accents
# Keeping the top 10000 occurring tokens

# %%
mean_scores  = []
interval = [10**-4, 10**-3, 10**-2, 10**-1, 1, 10, 10**2, 10**3]
for C in interval:
    clf = LinearSVC(C=C,class_weight='balanced')
    scores = cross_val_score(clf, X_train2, y_train, cv=10)
    mean_scores.append(np.mean(scores))

# %%
plt.plot(mean_scores) 
plt.show()

# %%
C_star = interval[np.argmax(mean_scores)]

clf2 = LinearSVC (C=C_star,class_weight='balanced')
clf2.fit(X_train2, y_train)
clf2.score(X_test2,y_test)
# Out:
# 0.82

# %%
clf2 = LinearSVC(C=C_star)
pred2 = eval_on_final_test(vectorizer2, clf2, alltxts, all_labs, txt_test, 2,l=1)
# score sur serveur 	0.804207831687

# %% [markdown]
# ## Version 3 : remove numbers + 2-grammes

# %%
vectorizer4 = build_vectorizer(text_train,n=(2,2),l=1)
X_train4 = vectorize_docs(vectorizer4, text_train) 
X_test4 = vectorize_docs(vectorizer4, text_test)
# Out:
# Removing numbers

# %%
vectorizer4.get_feature_names()
# Out:
# ['____ from',
#  '_____ level',
#  '______ and',
#  '____________________________________________ visit',
#  '_a fish',
#  '_a_night_at_the_roxbury_ takes',
#  '_a_night_at_the_roxbury_ you',
#  '_all_ of',
#  '_amadeus_ make',
#  '_american_beauty_ film',
#  '_american_psycho_ so',
#  '_and_ not',
#  '_animal house_',
#  '_anything_ large',
#  '_armageddon_ could',
#  '_babe_ is',
#  '_beloved_ intriguing',
#  '_beloved_ most',
#  '_beloved_ somewhat',
#  '_beloved_ ultimately',
#  '_blade runner_',
#  '_boogie nights_',
#  '_brazil_ or',
#  '_breakfast_ resembles',
#  '_breakfast_of_champions_ will',
#  '_but limited_',
#  '_can_ do',
#  '_casablanca_ does',
#  '_come_ from',
#  '_dead_man_ doesn',
#  '_dead_man_ lives',
#  '_dead_man_on_campus_ whatever',
#  '_death in',
#  '_do_ look',
#  '_do_ without',
#  '_does_ have',
#  '_does_ sing',
#  '_dog fancy_',
#  '_don do',
#  '_don t_',
#  '_double_team_ juicing',
#  '_double_team_ let',
#  '_dragon_ jason',
#  '_election good',
#  '_election_ but',
#  '_election_ contain',
#  '_election_ is',
#  '_election_ matthew',
#  '_election_ rely',
#  '_election_ so',
#  '_experience_ something',
#  '_fantastic_ however',
#  '_fear_and_loathing_in_las_vegas_ which',
#  '_ferris bueller_',
#  '_flirting with',
#  '_gag me',
#  '_gattaca_ than',
#  '_genius_ who',
#  '_ghost in',
#  '_great_ supporting',
#  '_happen_ they',
#  '_hard_ware and',
#  '_have_ seen',
#  '_heathers_ first',
#  '_highly_ recommended',
#  '_home alone_',
#  '_huge_ asshole',
#  '_in san',
#  '_in the',
#  '_into_ action',
#  '_is_ impressive',
#  '_is_ mish',
#  '_is_ once',
#  '_is_ that',
#  '_is_ the',
#  '_it wonderful',
#  '_jerry_maguire_ but',
#  '_jerry_maguire_ will',
#  '_kingpin_ left',
#  '_knock_off_ laughs',
#  '_knock_off_ leave',
#  '_knock_off_ lot',
#  '_knock_off_ the',
#  '_la promesse_',
#  '_last_ bruckheimer',
#  '_life is',
#  '_little women_',
#  '_loathe_ it',
#  '_lone star_',
#  '_looks_ good',
#  '_many_ more',
#  '_matewan_ instead',
#  '_matrix_ cutting',
#  '_melvin howard_',
#  '_mind eye_',
#  '_moby dick_',
#  '_monster_movie_ on',
#  '_mortal kombat_',
#  '_murder_ mystery',
#  '_not_ leave',
#  '_october sky_',
#  '_offscreen_ the',
#  '_onegin_ could',
#  '_original_ action',
#  '_patlabor the',
#  '_patlabor_ is',
#  '_pick_chucky_up_ so',
#  '_polish_wedding_ is',
#  '_polish_wedding_ plot',
#  '_pollock_ actor',
#  '_pollock_ as',
#  '_pollock_ embodies',
#  '_pollock_ encapsulates',
#  '_pollock_ experience',
#  '_pollock_ is',
#  '_pollock_ will',
#  '_poltergeist_ and',
#  '_porky s_',
#  '_practical magic_',
#  '_quite_ good',
#  '_real_ than',
#  '_real_ they',
#  '_reality bites_',
#  '_really_ bad',
#  '_really_ big',
#  '_really_ like',
#  '_really_ loathe',
#  '_really_ serve',
#  '_remains in',
#  '_require_ him',
#  '_roxbury_ lack',
#  '_roxbury_ play',
#  '_roxbury_ would',
#  '_rushmore_ and',
#  '_rushmore_ bill',
#  '_rushmore_ is',
#  '_rushmore_ released',
#  '_saturday_night_live_ the',
#  '_saved_by_the_bell_ alumnus',
#  '_saving private',
#  '_scarface_ this',
#  '_schindler list',
#  '_scream_ mary',
#  '_seven_nights_ could',
#  '_shaft_ is',
#  '_shaft_ keeps',
#  '_shaft_ movie',
#  '_shaft_ plot',
#  '_shaft_ should',
#  '_shaft_ that',
#  '_should_ have',
#  '_six_days _seven_nights_',
#  '_so much_',
#  '_soldier_ is',
#  '_soldier_ turned',
#  '_some_ scenes',
#  '_somewhere_ like',
#  '_survives_ with',
#  '_that_ find',
#  '_that_ more',
#  '_that_ type',
#  '_the bad',
#  '_the caveman',
#  '_the city',
#  '_the color',
#  '_the gap_',
#  '_the great',
#  '_the last',
#  '_the long',
#  '_the matrix_',
#  '_the scarlet',
#  '_the silence',
#  '_the thirteen',
#  '_the thirteenth',
#  '_the thirteeth',
#  '_the_last_days_of_disco_ which',
#  '_their_ books',
#  '_there_ the',
#  '_titus_ isn',
#  '_today_ to',
#  '_too_ bad',
#  '_twice_ the',
#  '_two_ things',
#  '_unbreakable_ is',
#  '_unbreakable_ suggests',
#  '_very_small_ mosaic',
#  '_wartime understanding',
#  '_what dreams',
#  '_will_ be',
#  '_would_ let',
#  'aa meetings',
#  'aaa minor',
#  'aaa team',
#  'aaaaaaaaah critique',
#  'aaliyah but',
#  'aaliyah trish',
#  'aaliyah who',
#  'aamir khan',
#  'aardman animation',
#  'aaron and',
#  'aaron eckhart',
#  'aaron edward',
#  'aaron gets',
#  'aaron is',
#  'aaron moor',
#  'aaron sandra',
#  'aaron schneider',
#  'aaron spelling',
#  'aaron steve',
#  'abandon are',
#  'abandon his',
#  'abandon naturally',
#  'abandon the',
#  'abandon their',
#  'abandon them',
#  'abandon this',
#  'abandoned and',
#  'abandoned by',
#  'abandoned church',
#  'abandoned cruiser',
#  'abandoned him',
#  'abandoned house',
#  'abandoned left',
#  'abandoned mansion',
#  'abandoned novalee',
#  'abandoned on',
#  'abandoned or',
#  'abandoned scrutinize',
#  'abandoned segments',
#  'abandoned shed',
#  'abandoned spaceship',
#  'abandoned steelworks',
#  'abandoned theater',
#  'abandoned warehouse',
#  'abandoned when',
#  'abandoned wing',
#  'abandoning his',
#  'abandonment by',
#  'abandonment of',
#  'abandons her',
#  'abandons him',
#  'abandons his',
#  'abandons much',
#  'abba tunes',
#  'abbe handsome',
#  'abbe lusts',
#  'abberation he',
#  'abberline johnny',
#  'abberline widower',
#  'abbott would',
#  'abbotts who',
#  'abbreviated bedhopping',
#  'abby asks',
#  'abby assuming',
#  'abby furthering',
#  'abby is',
#  'abby kohn',
#  'abby mistakes',
#  'abby relates',
#  'abby talk',
#  'abby tells',
#  'abby though',
#  'abby when',
#  'abc sabrina',
#  'abc then',
#  'abc wonderful',
#  'abdomen as',
#  'abdomen in',
#  'abducted and',
#  'abducted dr',
#  'abducted mctiernan',
#  'abductees before',
#  'abduction in',
#  'abduction scenarios',
#  'abduction scene',
#  'abductions it',
#  'abe over',
#  'abe petrovsky',
#  'abel ferrera',
#  'aberdeen could',
#  'aberdeen doesn',
#  'aberdeen is',
#  'aberdeen rampling',
#  'aberdeen scotland',
#  'aberdeen strives',
#  'aberdeen the',
#  'aberration an',
#  'aberration in',
#  'abetted by',
#  'abetting is',
#  'abider he',
#  'abides by',
#  'abilities ahem',
#  'abilities and',
#  'abilities are',
#  'abilities as',
#  'abilities at',
#  'abilities but',
#  'abilities consequently',
#  'abilities differ',
#  'abilities don',
#  'abilities he',
#  'abilities her',
#  'abilities in',
#  'abilities look',
#  'abilities of',
#  'abilities she',
#  'abilities shine',
#  'abilities the',
#  'abilities then',
#  'abilities to',
#  'abilities were',
#  'abilities what',
#  'abilities while',
#  'ability almost',
#  'ability and',
#  'ability at',
#  'ability between',
#  'ability but',
#  'ability catherine',
#  'ability due',
#  'ability from',
#  'ability hollow',
#  'ability in',
#  'ability mr',
#  'ability nor',
#  'ability of',
#  'ability thankfully',
#  'ability to',
#  'ability unfortunately',
#  'ability when',
#  'ability which',
#  'ability will',
#  'ability with',
#  'abject cruelty',
#  'able assists',
#  'able choose',
#  'able direction',
#  'able know',
#  'able picture',
#  'able pilot',
#  'able to',
#  'ably abetted',
#  'ably assumes',
#  'ably backed',
#  'ably built',
#  'ably captures',
#  'ably manages',
#  'ably shows',
#  'ably supported',
#  'abnormal as',
#  'abnormally reticent',
#  'abo about',
#  'abo needs',
#  'aboard delivers',
#  'aboard it',
#  'aboard just',
#  'aboard lifeboat',
#  'aboard nuclear',
#  'aboard spaceship',
#  'aboard speeding',
#  'aboard supply',
#  'aboard the',
#  'aboard titanic',
#  'aboard with',
#  'abode and',
#  'abode somewhere',
#  'abode where',
#  'abolish child',
#  'abolish these',
#  'abominable if',
#  'abominable thriller',
#  'abomination and',
#  'abomination film',
#  'aborbed by',
#  'aborigine manic',
#  'aborted wedding',
#  'abortion clinic',
#  'abortion collection',
#  'abortion it',
#  'abortion this',
#  'abortions instead',
#  'abortions with',
#  'abortive stab',
#  'abound but',
#  'abound in',
#  'abound nothing',
#  'abound rudy',
#  'abound so',
#  'abound that',
#  'abound the',
#  'abound these',
#  'abounded while',
#  'abounds including',
#  'abounds with',
#  'about _roxbury_',
#  'about about',
#  'about absolutely',
#  'about accomplishing',
#  'about action',
#  'about adam',
#  'about after',
#  'about afterwards',
#  'about alessa',
#  'about alfred',
#  'about alicia',
#  'about alien',
#  'about aliens',
#  'about all',
#  'about alligators',
#  'about alternate',
#  'about america',
#  'about american',
#  'about an',
#  'about and',
#  'about anderson',
#  'about annie',
#  'about another',
#  'about any',
#  'about anybody',
#  'about anyone',
#  'about anything',
#  'about appearing',
#  'about april',
#  'about arab',
#  'about are',
#  'about as',
#  'about at',
#  'about autobiographical',
#  'about ballroom',
#  'about band',
#  'about baseball',
#  'about beating',
#  'about because',
#  'about being',
#  'about bewildered',
#  'about black',
#  'about blacks',
#  'about booze',
#  'about both',
#  'about boundaries',
#  'about boyfriends',
#  'about briefly',
#  'about brilliant',
#  'about brooklyn',
#  'about bubby',
#  'about bunch',
#  'about burning',
#  'about but',
#  'about by',
#  'about calling',
#  'about callousness',
#  'about can',
#  'about carly',
#  'about cats',
#  'about celebrity',
#  'about chance',
#  'about change',
#  'about character',
#  'about characters',
#  'about charlie',
#  'about chinese',
#  'about christ',
#  'about chuckling',
#  'about circumcision',
#  'about city',
#  'about civic',
#  'about class',
#  'about cleavage',
#  'about coitus',
#  'about cold',
#  'about comedy',
#  'about comparing',
#  'about computers',
#  'about conducting',
#  'about conscience',
#  'about consequences',
#  'about construction',
#  'about contact',
#  'about corey',
#  'about cornelius',
#  'about couple',
#  'about coutroom',
#  'about coven',
#  'about crawford',
#  'about creating',
#  'about criminal',
#  'about critically',
#  'about crocodiles',
#  'about culkin',
#  'about daryl',
#  'about de',
#  'about dead',
#  'about dealing',
#  'about death',
#  'about decade',
#  'about deceiver',
#  'about deep',
#  'about deeply',
#  'about denise',
#  'about derek',
#  'about dern',
#  'about des',
#  'about details',
#  'about devastation',
#  'about diamonds',
#  'about direction',
#  'about director',
#  'about disaster',
#  'about diversity',
#  'about dna',
#  'about doctor',
#  'about documentary',
#  'about dog',
#  'about douglas',
#  'about dozen',
#  'about drama',
#  'about drew',
#  'about drunken',
#  'about duchovny',
#  'about dumas',
#  'about dying',
#  'about each',
#  'about eachother',
#  'about eight',
#  'about either',
#  'about election',
#  'about empty',
#  'about ergonomics',
#  'about eve',
#  'about every',
#  'about everyone',
#  'about everything',
#  'about evil',
#  'about ex',
#  'about exacting',
#  'about existence',
#  'about explaining',
#  'about explicit',
#  'about exploring',
#  'about extraterrestrial',
#  'about face',
#  'about faggots',
#  'about falsely',
#  'about family',
#  'about farts',
#  'about fate',
#  'about fell',
#  'about female',
#  'about fernando',
#  'about few',
#  'about fictious',
#  'about fifteen',
#  'about fifty',
#  'about fight',
#  'about fighting',
#  'about film',
#  'about final',
#  'about finding',
#  'about fire',
#  'about five',
#  'about flubber',
#  'about for',
#  'about forlani',
#  'about forty',
#  'about four',
#  'about francis',
#  'about frequency',
#  'about friendship',
#  'about from',
#  'about fun',
#  'about future',
#  'about gambling',
#  'about gangbangers',
#  'about garret',
#  'about gatewood',
#  'about gavin',
#  'about gay',
#  'about gays',
#  'about genuine',
#  'about george',
#  'about geronimo',
#  'about getting',
#  'about gia',
#  'about girl',
#  'about go',
#  'about god',
#  'about gods',
#  'about godzilla',
#  'about good',
#  'about government',
#  'about gripping',
#  'about grocery',
#  'about group',
#  'about guns',
#  'about gus',
#  'about guy',
#  'about guys',
#  'about half',
#  'about halfway',
#  'about hallucinatory',
#  'about happily',
#  'about hassidic',
#  'about hatred',
#  'about having',
#  'about helping',
#  'about helpless',
#  'about her',
#  'about here',
#  'about herself',
#  'about him',
#  'about himself',
#  'about hip',
#  'about hired',
#  'about his',
#  'about hisses',
#  'about history',
#  'about hmos',
#  'about hollywood',
#  'about holy',
#  'about home',
#  'about honesty',
#  'about horror',
#  'about hotel',
#  'about how',
#  'about howie',
#  'about hugh',
#  'about human',
#  'about humanity',
#  'about hundred',
#  'about if',
#  'about ignored',
#  'about images',
#  'about impact',
#  'about impossible',
#  'about in',
#  'about infidelity',
#  'about insectopia',
#  'about instead',
#  'about instinct',
#  'about intelligent',
#  'about intrigue',
#  'about ireland',
#  'about irrelevant',
#  'about is',
#  'about isolated',
#  'about issues',
#  'about it',
#  'about its',
#  'about itself',
#  'about jack',
#  'about jackie',
#  'about jackson',
#  'about jaws',
#  'about jb',
#  'about jealousy',
#  'about jennifer',
#  'about jerry',
#  'about jesus',
#  'about jews',
#  'about jill',
#  'about jimmy',
#  'about joe',
#  'about jones',
#  'about judging',
#  'about jumping',
#  'about keeping',
#  'about kevin',
#  'about kicking',
#  'about killing',
#  'about kimble',
#  'about kirk',
#  'about kissing',
#  'about labute',
#  'about lady',
#  'about large',
#  'about las',
#  'about later',
#  'about law',
#  'about lawrence',
#  'about lawyer',
#  'about left',
#  'about lesbianism',
#  'about life',
#  'about like',
#  'about limping',
#  'about listening',
#  'about literary',
#  'about lost',
#  'about love',
#  'about loving',
#  'about loyalty',
#  'about lucas',
#  'about main',
#  'about making',
#  'about male',
#  'about mallory',
#  'about man',
#  'about many',
#  'about margaret',
#  'about marilyn',
#  'about mary',
#  'about mass',
#  'about matters',
#  'about max',
#  'about me',
#  'about medical',
#  'about men',
#  'about message',
#  'about midway',
#  'about might',
#  'about million',
#  'about minding',
#  'about minors',
#  'about minus',
#  'about minute',
#  'about mismatched',
#  'about misunderstood',
#  'about misuse',
#  'about mizrahi',
#  'about money',
#  'about morals',
#  'about most',
#  'about movie',
#  'about movies',
#  'about mr',
#  'about much',
#  'about multiple',
#  'about mummies',
#  'about murderer',
#  'about murphy',
#  'about music',
#  'about my',
#  'about mythical',
#  'about naked',
#  'about nature',
#  'about neither',
#  'about nerdy',
#  'about nicole',
#  'about nielsen',
#  'about nine',
#  'about no',
#  'about nor',
#  'about norris',
#  'about not',
#  'about nothing',
#  'about now',
#  'about nutrition',
#  'about obstetrics',
#  'about odette',
#  'about oh',
#  'about oliver',
#  'about on',
#  'about once',
#  'about one',
#  'about oppressed',
#  'about ordell',
#  'about originality',
#  'about oscars',
#  'about our',
#  'about over',
#  'about overcoming',
#  'about overweight',
#  'about pair',
#  'about pammy',
#  'about paying',
#  'about people',
#  'about person',
#  'about pimp',
#  'about place',
#  'about placing',
#  'about planetary',
#  'about playing',
#  'about plot',
#  'about pocahontas',
#  'about poker',
#  'about poking',
#  'about police',
#  'about political',
#  'about politics',
#  'about poor',
#  'about pop',
#  'about porky',
#  'about possessed',
#  'about possible',
#  'about posturing',
#  'about pre',
#  'about precision',
#  'about previous',
#  'about princess',
#  'about private',
#  'about procreation',
#  'about prostitutes',
#  'about providing',
#  'about quarter',
#  'about quiet',
#  'about quite',
#  'about racism',
#  'about ralph',
#  'about rand',
#  'about rape',
#  'about ray',
#  'about reached',
#  'about reality',
#  'about realizing',
#  'about really',
#  'about redemption',
#  'about regular',
#  'about relationship',
#  'about religion',
#  'about request',
#  'about rescuing',
#  'about resolving',
#  'about resurrecting',
#  'about revealing',
#  'about reverse',
#  'about rhys',
#  'about richard',
#  'about rising',
#  'about rival',
#  'about rock',
#  'about rocket',
#  'about rounders',
#  'about routine',
#  'about ruben',
#  'about rubin',
#  'about run',
#  'about ryan',
#  'about sad',
#  'about salesmanship',
#  'about sara',
#  'about sarandon',
#  'about saving',
#  'about scandals',
#  'about script',
#  'about second',
#  'about seeing',
#  'about selflessness',
#  'about selling',
#  'about sequels',
#  'about serious',
#  'about seth',
#  'about sex',
#  'about sexual',
#  'about sharks',
#  'about she',
#  'about siblings',
#  'about sick',
#  'about simply',
#  'about simulated',
#  'about singles',
#  'about siskel',
#  'about six',
#  'about sketch',
#  'about slavery',
#  'about slaying',
#  'about small',
#  'about smart',
#  'about smith',
#  'about smoking',
#  'about snipers',
#  'about snowmen',
#  'about so',
#  'about society',
#  'about some',
#  'about something',
#  'about somewhere',
#  'about sorry',
#  'about special',
#  'about species',
#  'about spoofing',
#  'about spooky',
#  'about stalkers',
#  'about starting',
#  'about staying',
#  'about steiger',
#  'about stepping',
#  'about still',
#  'about story',
#  'about stretch',
#  'about stripping',
#  'about stuart',
#  'about style',
#  'about success',
#  'about such',
#  'about suddenly',
#  'about sue',
#  'about suicidal',
#  'about superman',
#  'about suspense',
#  'about syd',
#  'about taking',
#  'about talking',
#  'about tarzan',
#  'about techie',
#  'about teenagers',
#  'about telling',
#  'about ten',
#  'about than',
#  'about thandie',
#  'about thanking',
#  'about that',
#  'about the',
#  'about their',
#  'about them',
#  'about themselves',
#  'about then',
#  'about there',
#  'about thereafter',
#  'about these',
#  'about they',
#  'about things',
#  'about third',
#  'about thirsting',
#  'about thirty',
#  'about this',
#  'about thoroughly',
#  'about those',
#  'about though',
#  'about thousand',
#  'about three',
#  'about throwing',
#  'about tim',
#  'about time',
#  'about titanic',
#  'about to',
#  'about today',
#  'about tom',
#  'about tone',
#  'about toys',
#  'about tragic',
#  'about truth',
#  'about trying',
#  'about twenty',
#  'about twilight',
#  'about twister',
#  'about two',
#  'about ufos',
#  'about unless',
#  'about us',
#  'about using',
#  'about usually',
#  'about vampire',
#  'about vampires',
#  'about vanity',
#  'about varsity',
#  'about ve',
#  'about very',
#  'about vexatious',
#  'about viewing',
#  'about villain',
#  'about viscera',
#  'about visions',
#  'about wag',
#  'about war',
#  'about warp',
#  'about watching',
#  'about weather',
#  'about whacked',
#  'about what',
#  'about when',
#  'about where',
#  'about whether',
#  'about which',
#  'about who',
#  'about whom',
#  'about whose',
#  'about why',
#  'about wild',
#  'about willard',
#  'about wing',
#  'about wiseguy',
#  'about with',
#  'about without',
#  'about witnessing',
#  'about woman',
#  'about women',
#  'about world',
#  'about writing',
#  'about year',
#  'about you',
#  'about young',
#  'about your',
#  'about yourself',
#  'about yuppies',
#  'about zack',
#  'about zoe',
#  'abouts this',
#  'above after',
#  'above all',
#  'above am',
#  'above among',
#  'above and',
#  'above any',
#  'above are',
#  'above average',
#  'above bates',
#  'above but',
#  'above crashing',
#  'above everything',
#  ...]

# %%
mean_scores  = []
interval = [10**-4, 10**-3, 10**-2, 10**-1, 1, 10, 10**2, 10**3]
for C in interval:
    clf = LinearSVC(C=C,class_weight='balanced')
    scores = cross_val_score(clf, X_train4, y_train, scoring='f1_weighted', cv=10)
    mean_scores.append(np.mean(scores))

# %%
plt.plot(mean_scores) 
plt.show()

# %%
C_star = interval[np.argmax(mean_scores)]
clf4 = LinearSVC (C=C_star,class_weight='balanced')
clf4.fit(X_train4, y_train)
y_pred = clf4.predict(X_test4)
f1_score(y_test,y_pred,pos_label=-1, average='binary')
# Out:
# 0.8019480519480519

# %%
clf4 = LinearSVC(C=C_star)
pred4 = eval_on_final_test(vectorizer4, clf4, alltxts, all_labs, txt_test, 4,l=1)

# %% [markdown]
# ## Version 5 : remove numbers + 3-grammes

# %%
vectorizer5 = build_vectorizer(text_train,n=(3,3),l=1)
X_train5 = vectorize_docs(vectorizer5, text_train) 
X_test5 = vectorize_docs(vectorizer5, text_test)
# Out:
# Removing numbers

# %%
vectorizer5.get_feature_names()
# Out:
# ['____ from hell',
#  '_____ level in',
#  '______ and frears',
#  '______ and jack',
#  '____________________________________________ visit charlie',
#  '_a fish called',
#  '_a_night_at_the_roxbury_ takes an',
#  '_a_night_at_the_roxbury_ you ll',
#  '_all_ of them',
#  '_amadeus_ make it',
#  '_american_beauty_ film that',
#  '_american_psycho_ so it',
#  '_and_ not funny',
#  '_animal house_ surprisingly',
#  '_anything_ large enough',
#  '_armageddon_ could ever',
#  '_babe_ is sent',
#  '_beloved_ intriguing aspects',
#  '_beloved_ most memorable',
#  '_beloved_ somewhat of',
#  '_beloved_ ultimately tells',
#  '_blade runner_ co',
#  '_blade runner_ is',
#  '_boogie nights_ and',
#  '_brazil_ or perhaps',
#  '_breakfast_ resembles in',
#  '_breakfast_of_champions_ will hollywood',
#  '_but limited_ babe',
#  '_can_ do better',
#  '_casablanca_ does wonderful',
#  '_come_ from that',
#  '_dead_man_ doesn grow',
#  '_dead_man_ lives up',
#  '_dead_man_on_campus_ whatever morbid',
#  '_death in venice',
#  '_do_ look incredible',
#  '_do_ without giving',
#  '_does_ have is',
#  '_does_ sing sandra',
#  '_dog fancy_ the',
#  '_don do it_',
#  '_don t_ involve',
#  '_double_team_ juicing up',
#  '_double_team_ let alone',
#  '_dragon_ jason scott',
#  '_election good film',
#  '_election_ but the',
#  '_election_ contain so',
#  '_election_ is the',
#  '_election_ matthew broderick',
#  '_election_ rely upon',
#  '_election_ so disappointing',
#  '_experience_ something about',
#  '_fantastic_ however much',
#  '_fear_and_loathing_in_las_vegas_ which was',
#  '_ferris bueller_ and',
#  '_flirting with disaster_',
#  '_gag me with',
#  '_gattaca_ than _the',
#  '_genius_ who wants',
#  '_ghost in the',
#  '_great_ supporting cast',
#  '_happen_ they re',
#  '_hard_ware and other',
#  '_have_ seen _jerry_maguire_',
#  '_heathers_ first lastly',
#  '_highly_ recommended by',
#  '_home alone_ do',
#  '_huge_ asshole more',
#  '_in san francisco_',
#  '_in the company',
#  '_into_ action movies',
#  '_is_ impressive but',
#  '_is_ mish mosh',
#  '_is_ once the',
#  '_is_ that good',
#  '_is_ the movie',
#  '_it wonderful life_',
#  '_jerry_maguire_ but the',
#  '_jerry_maguire_ will only',
#  '_kingpin_ left negative',
#  '_knock_off_ laughs van',
#  '_knock_off_ leave much',
#  '_knock_off_ lot of',
#  '_knock_off_ the respect',
#  '_la promesse_ and',
#  '_last_ bruckheimer production',
#  '_life is beautiful_',
#  '_little women_ somewhere',
#  '_loathe_ it when',
#  '_lone star_ here',
#  '_looks_ good but',
#  '_many_ more dot',
#  '_matewan_ instead of',
#  '_matrix_ cutting edge',
#  '_melvin howard_ director',
#  '_mind eye_ videos',
#  '_moby dick_ is',
#  '_monster_movie_ on the',
#  '_mortal kombat_ paul',
#  '_murder_ mystery if',
#  '_not_ leave the',
#  '_october sky_ far',
#  '_october sky_ found',
#  '_october sky_ offers',
#  '_offscreen_ the audience',
#  '_onegin_ could have',
#  '_original_ action sequences',
#  '_patlabor the movie_',
#  '_patlabor_ is foremost',
#  '_pick_chucky_up_ so the',
#  '_polish_wedding_ is the',
#  '_polish_wedding_ plot complications',
#  '_pollock_ actor ed',
#  '_pollock_ as well',
#  '_pollock_ embodies the',
#  '_pollock_ encapsulates the',
#  '_pollock_ experience by',
#  '_pollock_ is all',
#  '_pollock_ will alienate',
#  '_poltergeist_ and ends',
#  '_porky s_ or',
#  '_practical magic_ mesmerizing',
#  '_quite_ good enough',
#  '_real_ than the',
#  '_real_ they are',
#  '_reality bites_ and',
#  '_really_ bad parts',
#  '_really_ big bomb',
#  '_really_ big desk',
#  '_really_ like sarah',
#  '_really_ loathe it',
#  '_really_ serve sigh',
#  '_remains in the',
#  '_require_ him to',
#  '_roxbury_ lack of',
#  '_roxbury_ play very',
#  '_roxbury_ would have',
#  '_rushmore_ and novel',
#  '_rushmore_ and the',
#  '_rushmore_ bill murray',
#  '_rushmore_ is the',
#  '_rushmore_ released few',
#  '_saturday_night_live_ the roxbury',
#  '_saved_by_the_bell_ alumnus gosselaar',
#  '_saving private ryan_',
#  '_scarface_ this is',
#  '_schindler list the',
#  '_scream_ mary sunniness',
#  '_seven_nights_ could be',
#  '_shaft_ is not',
#  '_shaft_ keeps that',
#  '_shaft_ movie does',
#  '_shaft_ plot doesn',
#  '_shaft_ should be',
#  '_shaft_ that of',
#  '_should_ have played',
#  '_six_days _seven_nights_ could',
#  '_so much_ on',
#  '_soldier_ is proof',
#  '_soldier_ is the',
#  '_soldier_ turned out',
#  '_some_ scenes which',
#  '_somewhere_ like to',
#  '_survives_ with charcoal',
#  '_that_ find very',
#  '_that_ more than',
#  '_that_ type of',
#  '_the bad news',
#  '_the caveman valentine_',
#  '_the city of',
#  '_the color purple_',
#  '_the gap_ and',
#  '_the great dictator_',
#  '_the last samurai_',
#  '_the long kiss',
#  '_the matrix_ which',
#  '_the scarlet letter_',
#  '_the silence of',
#  '_the thirteen floor_',
#  '_the thirteenth floor_',
#  '_the thirteeth floor_',
#  '_the_last_days_of_disco_ which wasn',
#  '_their_ books during',
#  '_there_ the murky',
#  '_titus_ isn complete',
#  '_today_ to clean',
#  '_too_ bad if',
#  '_twice_ the fact',
#  '_two_ things everyone',
#  '_unbreakable_ is mature',
#  '_unbreakable_ suggests that',
#  '_very_small_ mosaic tiles',
#  '_wartime understanding and',
#  '_what dreams may',
#  '_will_ be able',
#  '_would_ let you',
#  'aa meetings shandling',
#  'aa meetings to',
#  'aaa minor league',
#  'aaa team he',
#  'aaa team the',
#  'aaaaaaaaah critique completely',
#  'aaliyah but it',
#  'aaliyah trish day',
#  'aaliyah who weren',
#  'aamir khan muslim',
#  'aardman animation produced',
#  'aaron and is',
#  'aaron eckhart and',
#  'aaron eckhart lauren',
#  'aaron eckhart playing',
#  'aaron edward norton',
#  'aaron gets weirder',
#  'aaron is convincing',
#  'aaron moor who',
#  'aaron sandra bullock',
#  'aaron schneider is',
#  'aaron spelling couple',
#  'aaron spelling would',
#  'aaron steve martin',
#  'abandon are sure',
#  'abandon his friends',
#  'abandon his goal',
#  'abandon his unique',
#  'abandon naturally there',
#  'abandon the farm',
#  'abandon the principle',
#  'abandon their rescue',
#  'abandon them at',
#  'abandon this is',
#  'abandoned and alone',
#  'abandoned and beaten',
#  'abandoned by her',
#  'abandoned church is',
#  'abandoned cruiser and',
#  'abandoned him and',
#  'abandoned house they',
#  'abandoned house to',
#  'abandoned left on',
#  'abandoned mansion and',
#  'abandoned mansion at',
#  'abandoned novalee in',
#  'abandoned on the',
#  'abandoned or sealed',
#  'abandoned scrutinize her',
#  'abandoned segments that',
#  'abandoned shed she',
#  'abandoned spaceship and',
#  'abandoned steelworks which',
#  'abandoned theater whose',
#  'abandoned warehouse when',
#  'abandoned when her',
#  'abandoned wing of',
#  'abandoning his facial',
#  'abandonment by her',
#  'abandonment of paradise',
#  'abandons her maroon',
#  'abandons her old',
#  'abandons her to',
#  'abandons him to',
#  'abandons his old',
#  'abandons much of',
#  'abba tunes which',
#  'abbe handsome charming',
#  'abbe lusts for',
#  'abberation he continues',
#  'abberline johnny depp',
#  'abberline widower has',
#  'abbott would have',
#  'abbotts who eventually',
#  'abbreviated bedhopping montage',
#  'abby asks her',
#  'abby asks him',
#  'abby assuming the',
#  'abby furthering the',
#  'abby is thrown',
#  'abby kohn and',
#  'abby mistakes her',
#  'abby relates to',
#  'abby talk radio',
#  'abby tells her',
#  'abby though knows',
#  'abby when they',
#  'abc sabrina the',
#  'abc then fox',
#  'abc wonderful world',
#  'abdomen as an',
#  'abdomen in sloppy',
#  'abducted and the',
#  'abducted and tortured',
#  'abducted dr kate',
#  'abducted mctiernan wakes',
#  'abductees before she',
#  'abduction in the',
#  'abduction scenarios that',
#  'abduction scene all',
#  'abductions it sad',
#  'abe over the',
#  'abe petrovsky while',
#  'abel ferrera china',
#  'aberdeen could have',
#  'aberdeen doesn know',
#  'aberdeen is never',
#  'aberdeen rampling is',
#  'aberdeen scotland by',
#  'aberdeen strives for',
#  'aberdeen the differences',
#  'aberration an incipient',
#  'aberration in film',
#  'abetted by director',
#  'abetted by wonderfully',
#  'abetting is the',
#  'abider he has',
#  'abides by his',
#  'abilities ahem to',
#  'abilities and how',
#  'abilities and uses',
#  'abilities are evident',
#  'abilities are limited',
#  'abilities are more',
#  'abilities as for',
#  'abilities at the',
#  'abilities but otherwise',
#  'abilities consequently he',
#  'abilities differ all',
#  'abilities don seem',
#  'abilities he displays',
#  'abilities he needs',
#  'abilities her acting',
#  'abilities in order',
#  'abilities in the',
#  'abilities look good',
#  'abilities of backup',
#  'abilities she tries',
#  'abilities shine in',
#  'abilities the story',
#  'abilities then there',
#  'abilities to center',
#  'abilities to start',
#  'abilities to support',
#  'abilities were not',
#  'abilities what letdown',
#  'abilities while emotionally',
#  'ability almost every',
#  'ability and he',
#  'ability and his',
#  'ability and is',
#  'ability and precision',
#  'ability and promotes',
#  'ability and then',
#  'ability at making',
#  'ability between them',
#  'ability but some',
#  'ability catherine zeta',
#  'ability due to',
#  'ability from chuck',
#  'ability hollow man',
#  'ability in moviemaking',
#  'ability mr heston',
#  'ability nor is',
#  'ability of different',
#  'ability of isabella',
#  'ability of sequoia',
#  'ability thankfully for',
#  'ability to appreciate',
#  'ability to be',
#  'ability to become',
#  'ability to both',
#  'ability to carry',
#  'ability to challenge',
#  'ability to choose',
#  'ability to convey',
#  'ability to create',
#  'ability to direct',
#  'ability to do',
#  'ability to entertain',
#  'ability to fly',
#  'ability to fold',
#  'ability to forge',
#  'ability to gain',
#  'ability to get',
#  'ability to give',
#  'ability to handle',
#  'ability to heal',
#  'ability to impress',
#  'ability to kill',
#  'ability to lie',
#  'ability to listen',
#  'ability to make',
#  'ability to mind',
#  'ability to move',
#  'ability to mystically',
#  'ability to overcome',
#  'ability to pack',
#  'ability to perfect',
#  'ability to play',
#  'ability to pull',
#  'ability to put',
#  'ability to quickly',
#  'ability to reflect',
#  'ability to slow',
#  'ability to speak',
#  'ability to strategize',
#  'ability to suspend',
#  'ability to take',
#  'ability to talk',
#  'ability to tell',
#  'ability to think',
#  'ability to use',
#  'ability to write',
#  'ability unfortunately any',
#  'ability when the',
#  'ability when this',
#  'ability which she',
#  'ability will serve',
#  'ability with actors',
#  'ability with his',
#  'ability with the',
#  'abject cruelty to',
#  'able assists from',
#  'able choose for',
#  'able direction are',
#  'able know what',
#  'able picture of',
#  'able pilot west',
#  'able to accessorize',
#  'able to afford',
#  'able to appreciate',
#  'able to bear',
#  'able to bend',
#  'able to blossom',
#  'able to break',
#  'able to bring',
#  'able to capitalize',
#  'able to carry',
#  'able to coast',
#  'able to come',
#  'able to communicate',
#  'able to control',
#  'able to convey',
#  'able to convince',
#  'able to create',
#  'able to deliver',
#  'able to demonstrate',
#  'able to determine',
#  'able to discover',
#  'able to disguise',
#  'able to do',
#  'able to ease',
#  'able to easily',
#  'able to elude',
#  'able to enjoy',
#  'able to enliven',
#  'able to entertain',
#  'able to escape',
#  'able to fight',
#  'able to find',
#  'able to follow',
#  'able to forget',
#  'able to fulfill',
#  'able to gain',
#  'able to gaze',
#  'able to generate',
#  'able to get',
#  'able to give',
#  'able to go',
#  'able to guess',
#  'able to handle',
#  'able to have',
#  'able to help',
#  'able to highlight',
#  'able to hold',
#  'able to hurt',
#  'able to identify',
#  'able to invigorate',
#  'able to keep',
#  'able to know',
#  'able to leap',
#  'able to let',
#  'able to locate',
#  'able to look',
#  'able to maintain',
#  'able to make',
#  'able to meet',
#  'able to momentarily',
#  'able to move',
#  'able to nab',
#  'able to negotiate',
#  'able to not',
#  'able to notice',
#  'able to obtain',
#  'able to overcome',
#  'able to paint',
#  'able to pass',
#  'able to perfectly',
#  'able to photograph',
#  'able to play',
#  'able to plug',
#  'able to portray',
#  'able to predict',
#  'able to present',
#  'able to proceed',
#  'able to provide',
#  'able to pull',
#  'able to put',
#  'able to recognize',
#  'able to reconcile',
#  'able to relate',
#  'able to remember',
#  'able to reveal',
#  'able to review',
#  'able to rise',
#  'able to run',
#  'able to satisfy',
#  'able to save',
#  'able to say',
#  'able to see',
#  'able to serve',
#  'able to shallowly',
#  'able to share',
#  'able to shed',
#  'able to show',
#  'able to sit',
#  'able to slip',
#  'able to somewhat',
#  'able to sort',
#  'able to stand',
#  'able to stop',
#  'able to successfully',
#  'able to suspend',
#  'able to take',
#  'able to talk',
#  'able to taste',
#  'able to tell',
#  'able to the',
#  'able to think',
#  'able to thoroughly',
#  'able to top',
#  'able to track',
#  'able to truly',
#  'able to trust',
#  'able to turn',
#  'able to understand',
#  'able to use',
#  'able to view',
#  'able to walk',
#  'able to watch',
#  'able to withhold',
#  'able to withstand',
#  'able to work',
#  'able to zone',
#  'ably abetted by',
#  'ably assumes various',
#  'ably backed by',
#  'ably built during',
#  'ably captures the',
#  'ably manages to',
#  'ably shows that',
#  'ably supported by',
#  'abnormal as this',
#  'abnormally reticent hiding',
#  'abo about the',
#  'abo needs to',
#  'aboard delivers via',
#  'aboard it looks',
#  'aboard just as',
#  'aboard lifeboat you',
#  'aboard nuclear submarines',
#  'aboard spaceship whose',
#  'aboard speeding coach',
#  'aboard supply vessel',
#  'aboard the indianapolis',
#  'aboard the mechanical',
#  'aboard the medical',
#  'aboard the ship',
#  'aboard the sulaco',
#  'aboard the titanic',
#  'aboard titanic in',
#  'aboard with illusions',
#  'abode and wanting',
#  'abode somewhere in',
#  'abode where the',
#  'abolish child labor',
#  'abolish these types',
#  'abominable if you',
#  'abominable thriller julie',
#  'abomination and it',
#  'abomination film that',
#  'aborbed by her',
#  'aborigine manic russian',
#  'aborted wedding there',
#  'abortion clinic worker',
#  'abortion collection of',
#  'abortion it is',
#  'abortion this causes',
#  'abortions instead wondering',
#  'abortions with high',
#  'abortive stab at',
#  'abound but it',
#  'abound in football',
#  'abound in the',
#  'abound nothing wrong',
#  'abound rudy is',
#  'abound so do',
#  'abound that defy',
#  'abound that this',
#  'abound the days',
#  'abound these can',
#  'abounded while much',
#  'abounds including slapstick',
#  'abounds with little',
#  'about _roxbury_ lack',
#  'about about themselves',
#  'about absolutely anything',
#  'about accomplishing something',
#  'about action canadian',
#  'about adam does',
#  'about after all',
#  'about afterwards and',
#  'about afterwards will',
#  'about afterwards you',
#  'about alessa alessa',
#  'about alessa feelings',
#  'about alfred sickness',
#  'about alicia silverstone',
#  'about alien contact',
#  'about alien love',
#  'about aliens who',
#  'about all four',
#  'about all his',
#  'about all of',
#  'about all saw',
#  'about all that',
#  'about all the',
#  'about all this',
#  'about all those',
#  'about alligators in',
#  'about alternate realities',
#  'about america youth',
#  'about american beauty',
#  'about american high',
#  'about an action',
#  'about an actor',
#  'about an alien',
#  'about an armored',
#  'about an ecological',
#  'about an egotistical',
#  'about an errol',
#  'about an hour',
#  'about an idea',
#  'about an old',
#  'about an otherwise',
#  'about and chatter',
#  'about and general',
#  'about and his',
#  'about and identifying',
#  'about and somehow',
#  'about and the',
#  'about and therefore',
#  'about and well',
#  'about anderson intentions',
#  'about annie who',
#  'about another side',
#  'about another turn',
#  'about any character',
#  'about any federal',
#  'about any movie',
#  'about any of',
#  'about any other',
#  'about any thing',
#  'about anybody else',
#  'about anyone actually',
#  'about anyone but',
#  'about anyone in',
#  'about anyone the',
#  'about anyone uncomfortable',
#  'about anything at',
#  'about anything disturbing',
#  'about anything more',
#  'about anything or',
#  'about anything that',
#  'about anything to',
#  'about appearing nude',
#  'about april pfferpot',
#  'about arab mentality',
#  'about are inconsistent',
#  'about as anticlimactic',
#  'about as bad',
#  'about as bare',
#  'about as beautiful',
#  'about as believable',
#  'about as challenging',
#  'about as charming',
#  'about as clear',
#  'about as close',
#  'about as columnist',
#  'about as complex',
#  'about as contrived',
#  'about as detailed',
#  'about as entertaining',
#  'about as erotic',
#  'about as exciting',
#  'about as far',
#  'about as frightening',
#  'about as funny',
#  'about as generic',
#  'about as good',
#  'about as high',
#  'about as interesting',
#  'about as long',
#  'about as many',
#  'about as much',
#  'about as often',
#  'about as probable',
#  'about as strong',
#  'about as suspenseful',
#  'about as talented',
#  'about as the',
#  'about as uninspired',
#  'about as well',
#  'about at least',
#  'about autobiographical character',
#  'about ballroom dancing',
#  'about band of',
#  'about baseball players',
#  'about beating people',
#  'about because it',
#  'about because they',
#  'about being abandoned',
#  'about being english',
#  'about being hassled',
#  'about being in',
#  'about being kind',
#  'about being normal',
#  'about being salesman',
#  'about being the',
#  'about being there',
#  'about being with',
#  'about bewildered individual',
#  'about black ticket',
#  'about blacks was',
#  'about booze and',
#  'about both the',
#  'about boundaries at',
#  'about boyfriends out',
#  'about briefly but',
#  'about brilliant acting',
#  'about brooklyn where',
#  'about bubby and',
#  'about bunch of',
#  'about burning issues',
#  'about but also',
#  'about but capra',
#  'about but either',
#  'about but it',
#  'about but never',
#  'about but now',
#  'about but the',
#  'about by that',
#  'about by the',
#  'about calling the',
#  'about callousness and',
#  'about can save',
#  'about carly he',
#  'about cats and',
#  'about celebrity is',
#  'about chance to',
#  'about change left',
#  'about character development',
#  'about character or',
#  'about characters or',
#  'about charlie condition',
#  'about chinese law',
#  'about chinese musical',
#  'about christ as',
#  'about chuckling lone',
#  'about circumcision psychic',
#  'about city of',
#  'about civic responsibilities',
#  'about class differences',
#  'about cleavage power',
#  'about coitus interruptus',
#  'about cold emotionally',
#  'about comedy along',
#  'about comparing isn',
#  'about computers closer',
#  'about conducting experiments',
#  'about conscience stricken',
#  'about consequences hence',
#  'about construction and',
#  'about contact so',
#  'about corey haim',
#  'about cornelius ian',
#  'about couple guys',
#  'about coutroom movies',
#  'about coven of',
#  'about crawford in',
#  'about creating plan',
#  'about criminal investigation',
#  'about critically successful',
#  'about crocodiles they',
#  'about culkin insight',
#  'about daryl then',
#  'about daryl to',
#  'about de niro',
#  'about dead indian',
#  'about dealing with',
#  'about death but',
#  'about death children',
#  'about death is',
#  'about death star',
#  'about decade his',
#  'about deceiver is',
#  'about deep impact',
#  'about deeply developed',
#  'about denise richards',
#  'about derek how',
#  'about dern caretaker',
#  'about des is',
#  'about details it',
#  'about devastation instead',
#  'about diamonds are',
#  'about direction by',
#  'about director paul',
#  'about disaster it',
#  'about diversity and',
#  'about dna extraction',
#  'about doctor who',
#  'about documentary film',
#  'about dog of',
#  'about douglas being',
#  'about dozen ethical',
#  'about dozen times',
#  'about dozen writers',
#  'about drama or',
#  'about drew walks',
#  'about drunken master',
#  'about duchovny that',
#  'about dumas masterwork',
#  'about dying man',
#  'about each and',
#  'about each one',
#  'about each other',
#  'about each person',
#  'about eachother lives',
#  'about eachother once',
#  'about eight minute',
#  'about eight taels',
#  'about either davidtz',
#  'about either virtual',
#  'about election is',
#  'about empty desperate',
#  'about ergonomics one',
#  'about eve female',
#  'about every bad',
#  'about every conceivable',
#  'about every film',
#  'about every kind',
#  'about every level',
#  'about every shot',
#  'about every single',
#  'about every ten',
#  'about every woman',
#  'about everyone except',
#  'about everyone is',
#  'about everything expressed',
#  'about everything from',
#  'about everything his',
#  'about everything in',
#  'about everything including',
#  'about everything the',
#  'about everything while',
#  'about everything wild',
#  'about evil masquerading',
#  'about ex alchoholic',
#  'about exacting revenge',
#  'about existence it',
#  'about explaining every',
#  'about explicit sex',
#  'about exploring relationships',
#  'about extraterrestrial life',
#  'about face on',
#  'about faggots migrating',
#  'about falsely convicted',
#  'about family and',
#  'about family feud',
#  'about family relationships',
#  'about farts and',
#  'about fate the',
#  'about fell off',
#  'about female assassin',
#  'about fernando stormy',
#  'about few seconds',
#  'about fictious world',
#  'about fifteen feet',
#  'about fifteen minutes',
#  'about fifteen or',
#  'about fifty still',
#  'about fight club',
#  'about fighting the',
#  'about film making',
#  'about film whose',
#  'about final destination',
#  'about finding the',
#  'about fire in',
#  'about five and',
#  'about five minutes',
#  'about five times',
#  'about flubber is',
#  'about for weeks',
#  'about forlani ex',
#  'about forty five',
#  'about four different',
#  'about four guys',
#  'about four hearty',
#  'about four hours',
#  'about four or',
#  'about four sexually',
#  'about four teenage',
#  'about four times',
#  'about four years',
#  'about francis makeup',
#  'about frequency is',
#  'about friendship you',
#  'about from now',
#  'about fun songs',
#  'about future in',
#  'about gambling filmmaker',
#  'about gangbangers and',
#  'about garret relationship',
#  'about gatewood the',
#  'about gavin and',
#  'about gay individuals',
#  'about gay man',
#  'about gays and',
#  'about genuine yakuza',
#  'about george rod',
#  'about geronimo and',
#  'about geronimo is',
#  'about getting back',
#  'about getting in',
#  'about getting into',
#  'about getting it',
#  'about getting the',
#  'about gia for',
#  'about girl gang',
#  'about girl in',
#  'about girl power',
#  'about girl trying',
#  'about girl waiting',
#  'about go characters',
#  'about god and',
#  'about god by',
#  'about gods and',
#  'about godzilla being',
#  'about godzilla in',
#  'about godzilla reeks',
#  'about good will',
#  'about government conspiracies',
#  'about gripping drama',
#  'about grocery bagger',
#  'about group of',
#  'about guns jackson',
#  'about gus van',
#  'about guy called',
#  'about guys like',
#  'about half an',
#  'about half as',
#  'about half hour',
#  'about half notch',
#  'about half of',
#  'about half right',
#  'about half the',
#  'about half to',
#  'about half way',
#  'about halfway through',
#  'about hallucinatory ride',
#  'about happily everything',
#  'about hassidic culture',
#  'about hatred couldn',
#  'about having children',
#  'about having kids',
#  'about having to',
#  'about helping people',
#  'about helpless single',
#  'about her actual',
#  'about her asthmatic',
#  'about her breathtaking',
#  'about her character',
#  'about her desires',
#  'about her experiences',
#  'about her firm',
#  'about her future',
#  'about her gradual',
#  'about her guests',
#  'about her husband',
#  'about her immediate',
#  'about her is',
#  'about her lack',
#  ...]

# %%
mean_scores  = []
interval = [10**-4, 10**-3, 10**-2, 10**-1, 1, 10, 10**2, 10**3]
for C in interval:
    clf = LinearSVC(C=C,class_weight='balanced')
    scores = cross_val_score(clf, X_train5, y_train, scoring='f1_weighted', cv=10)
    mean_scores.append(np.mean(scores))

# %%
plt.plot(mean_scores) 
plt.show()

# %%
C_star = interval[np.argmax(mean_scores)]

clf5 = LinearSVC (C=C_star,class_weight='balanced')
clf5.fit(X_train5, y_train)
y_pred = clf5.predict(X_test5)
f1_score(y_test,y_pred,pos_label=-1, average='binary')
# Out:
# 0.7427701674277019

# %%
clf5 = LinearSVC(C=C_star)
pred5 = eval_on_final_test(vectorizer5, clf5, alltxts, all_labs, txt_test, 5,l=1)

# %% [markdown]
# ## Version 6 : uppercase /Removing accents/Keeping the top 10000 occurring tokens/removing stopwords   3-grammes

# %%
vectorizer6 = build_vectorizer(alltxts,stopwords=stop_words,\
                         b_lowercase=False, b_accent=False,\
                                           max_f=10000,n=(2,2),l=1)
X_train6 = vectorize_docs(vectorizer6, text_train) 
X_test6 = vectorize_docs(vectorizer6, text_test)
# Out:
# Removing numbers
# Keeping uppercase
# Removing accents
# Keeping the top 10000 occurring tokens

# %%
mean_scores  = []
interval = [10**-4, 10**-3, 10**-2, 10**-1, 1, 10, 10**2, 10**3]
for C in interval:
    clf = LinearSVC(C=C,class_weight='balanced')
    scores = cross_val_score(clf, X_train6, y_train, scoring='f1_weighted', cv=10)
    mean_scores.append(np.mean(scores))

# %%
plt.plot(mean_scores) 
plt.show()

# %%
C_star = interval[np.argmax(mean_scores)]

clf6 = LinearSVC (C=C_star,class_weight='balanced')
clf6.fit(X_train5, y_train)
y_pred = clf5.predict(X_test5)
f1_score(y_test,y_pred,pos_label=-1, average='binary')
# Out:
# 0.985172981878089

# %%
clf6 = LinearSVC(C=C_star)
pred6 = eval_on_final_test(vectorizer6, clf6, alltxts, all_labs, txt_test, 6,l=1)
